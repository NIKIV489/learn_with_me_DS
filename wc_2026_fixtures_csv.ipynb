# %%
import pandas as pd
a1=pd.read_csv("/content/Top 500 Movies Ranked by Combined Critics and Audience Scores.csv")
a1
# Out:
#      Rank                   Title  Year                   Genre  \
# 0       1           The Godfather  1972            Drama, Crime
# 1       2           Seven Samurai  1954           Action, Drama
# 2       3            12 Angry Men  1957                   Drama
# 3       4        Schindler's List  1993     Drama, History, War
# 4       5  The Godfather: Part II  1974            Drama, Crime
# ..    ...                     ...   ...                     ...
# 444   445                   Rocky  1976                   Drama
# 445   446          Phantom Thread  2017          Drama, Romance
# 446   447                Paterson  2016  Drama, Comedy, Romance
# 447   448                 Titanic  1997          Drama, Romance
# 448   449              Uncut Gems  2019  Drama, Thriller, Crime
#
#                       Director  \
# 0         Francis Ford Coppola
# 1               Akira Kurosawa
# 2                 Sidney Lumet
# 3             Steven Spielberg
# 4         Francis Ford Coppola
# ...

# %%
a1.head()
# Out:
#    Rank                   Title  Year                Genre  \
# 0     1           The Godfather  1972         Drama, Crime
# 1     2           Seven Samurai  1954        Action, Drama
# 2     3            12 Angry Men  1957                Drama
# 3     4        Schindler's List  1993  Drama, History, War
# 4     5  The Godfather: Part II  1974         Drama, Crime
#
#                Director                                               Cast  \
# 0  Francis Ford Coppola  Marlon Brando, Al Pacino, James Caan, Robert D...
# 1        Akira Kurosawa  Toshirō Mifune, Takashi Shimura, Yoshio Inaba,...
# 2          Sidney Lumet  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 3      Steven Spielberg  Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...
# 4  Francis Ford Coppola  Al Pacino, Robert Duvall, Diane Keaton, Robert...
#
#   Language                                               Plot  \
# 0       en  Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
a1.tail()
# Out:
#      Rank           Title  Year                   Genre  \
# 444   445           Rocky  1976                   Drama
# 445   446  Phantom Thread  2017          Drama, Romance
# 446   447        Paterson  2016  Drama, Comedy, Romance
# 447   448         Titanic  1997          Drama, Romance
# 448   449      Uncut Gems  2019  Drama, Thriller, Crime
#
#                       Director  \
# 444           John G. Avildsen
# 445       Paul Thomas Anderson
# 446               Jim Jarmusch
# 447              James Cameron
# 448  Josh Safdie, Benny Safdie
#
#                                                   Cast Language  \
# 444  Sylvester Stallone, Talia Shire, Burt Young, C...       en
# 445  Daniel Day-Lewis, Vicky Krieps, Lesley Manvill...       en
# 446  Adam Driver, Golshifteh Farahani, Nellie, Rizw...       en
# 447  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...       en
# 448  Adam Sandler, LaKeith Stanfield, Julia Fox, Ke...       en
#
# ...

# %%
a1.columns
# Out:
# Index(['Rank', 'Title', 'Year', 'Genre', 'Director', 'Cast', 'Language',
#        'Plot', 'Awards', 'Production', 'Flickmetrix_Score', 'IMDb_10',
#        'IMDb_100', 'IMDb_Votes', 'Metacritic', 'Critic_Rating_RT',
#        'Critic_Reviews', 'Audience_Rating', 'Audience_Reviews', 'Letterboxd',
#        'Letterboxd_Votes', 'Google_Score', 'Streaming_On', 'RT_URL', 'imdbID',
#        'Custom_Score'],
#       dtype='object')

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               449 non-null    int64
#  1   Title              449 non-null    object
#  2   Year               449 non-null    int64
#  3   Genre              449 non-null    object
#  4   Director           449 non-null    object
#  5   Cast               448 non-null    object
#  6   Language           449 non-null    object
#  7   Plot               449 non-null    object
#  8   Awards             324 non-null    object
#  9   Production         329 non-null    object
#  10  Flickmetrix_Score  449 non-null    float64
#  11  IMDb_10            449 non-null    float64
#  12  IMDb_100           449 non-null    float64
#  13  IMDb_Votes         449 non-null    int64
#  14  Metacritic         436 non-null    float64
#  15  Critic_Rating_RT   449 non-null    float64
# ...

# %%
a1.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Year                   0
# Genre                  0
# Director               0
# Cast                   1
# Language               0
# Plot                   0
# Awards               125
# Production           120
# Flickmetrix_Score      0
# IMDb_10                0
# IMDb_100               0
# IMDb_Votes             0
# Metacritic            13
# Critic_Rating_RT       0
# Critic_Reviews         0
# Audience_Rating       48
# Audience_Reviews       7
# Letterboxd             0
# Letterboxd_Votes       1
# Google_Score           3
# Streaming_On          30
# RT_URL                17
# imdbID                 0
# Custom_Score           0
# dtype: int64

# %%
obj=["Cast","Metacritic","Audience_Rating","Audience_Reviews","Letterboxd_Votes","Google_Score","Streaming_On","RT_URL"]
a1[obj]=a1[obj].fillna("Unknown")
a1
# Out:
#      Rank                   Title  Year                   Genre  \
# 0       1           The Godfather  1972            Drama, Crime
# 1       2           Seven Samurai  1954           Action, Drama
# 2       3            12 Angry Men  1957                   Drama
# 3       4        Schindler's List  1993     Drama, History, War
# 4       5  The Godfather: Part II  1974            Drama, Crime
# ..    ...                     ...   ...                     ...
# 444   445                   Rocky  1976                   Drama
# 445   446          Phantom Thread  2017          Drama, Romance
# 446   447                Paterson  2016  Drama, Comedy, Romance
# 447   448                 Titanic  1997          Drama, Romance
# 448   449              Uncut Gems  2019  Drama, Thriller, Crime
#
#                       Director  \
# 0         Francis Ford Coppola
# 1               Akira Kurosawa
# 2                 Sidney Lumet
# 3             Steven Spielberg
# 4         Francis Ford Coppola
# ...

# %%
a1.shape
# Out:
# (449, 26)

# %%
a1["Language"].value_counts()
# Out:
# Language
# en    334
# ja     21
# fr     20
# es     14
# it     11
# ko      8
# de      8
# zh      4
# pt      3
# da      3
# tr      3
# pl      2
# sv      2
# fa      2
# no      2
# cn      1
# ru      1
# id      1
# lv      1
# te      1
# ga      1
# ro      1
# he      1
# ar      1
# hi      1
# gl      1
# hu      1
# Name: count, dtype: int64

# %%
a1["Language"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Language'>

# %%
a1["Critic_Reviews"].value_counts()
# Out:
# Critic_Reviews
# 51     13
# 58      9
# 52      9
# 55      9
# 87      8
#        ..
# 271     1
# 293     1
# 310     1
# 256     1
# 235     1
# Name: count, Length: 176, dtype: int64

# %%
obj_cols = a1.select_dtypes(include="object").columns

a1[obj_cols] = a1[obj_cols].fillna("Unknown")

# %%
num_cols = a1.select_dtypes(include=["int64","float64"]).columns

a1[num_cols] = a1[num_cols].fillna(
    a1[num_cols].median()
)

# %%
a1["Awards"].value_counts().head()
# Out:
# Awards
# Unknown                   125
# 1 win.                      8
# 1 win & 1 nomination.       6
# 2 wins & 1 nomination.      3
# 3 wins & 1 nomination.      2
# Name: count, dtype: int64

# %%
a1["Audience_Rating"].describe()
# Out:
# count         449
# unique         27
# top       Unknown
# freq           48
# Name: Audience_Rating, dtype: object

# %%
a1["Streaming_On"] = a1["Streaming_On"].fillna("Not Available")

# %%
a1.info()

a1.select_dtypes(include="object").columns

a1.select_dtypes(include=["int64","float64"]).columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               449 non-null    int64
#  1   Title              449 non-null    object
#  2   Year               449 non-null    int64
#  3   Genre              449 non-null    object
#  4   Director           449 non-null    object
#  5   Cast               449 non-null    object
#  6   Language           449 non-null    object
#  7   Plot               449 non-null    object
#  8   Awards             449 non-null    object
#  9   Production         449 non-null    object
#  10  Flickmetrix_Score  449 non-null    float64
#  11  IMDb_10            449 non-null    float64
#  12  IMDb_100           449 non-null    float64
#  13  IMDb_Votes         449 non-null    int64
#  14  Metacritic         449 non-null    object
#  15  Critic_Rating_RT   449 non-null    float64
# ...

# %%
a1["Streaming_On"] = a1["Streaming_On"].fillna(a1["Streaming_On"].mode()[0])
a1["Streaming_On"]
# Out:
# 0      paramount, itunes, amzvid
# 1       hbo, itunes, amzvid, hbm
# 2                 itunes, amzvid
# 3                 itunes, amzvid
# 4      paramount, itunes, amzvid
#                  ...
# 444               itunes, amzvid
# 445               itunes, amzvid
# 446                        prime
# 447    paramount, itunes, amzvid
# 448               amzvid, itunes
# Name: Streaming_On, Length: 449, dtype: object

# %%
a1["Awards"] = a1["Awards"].fillna("No Awards")

# %%
a1["Awards_missing"] = a1["Awards"].isnull()

# %%
a1.dtypes
# Out:
# Rank                   int64
# Title                 object
# Year                   int64
# Genre                 object
# Director              object
# Cast                  object
# Language              object
# Plot                  object
# Awards                object
# Production            object
# Flickmetrix_Score    float64
# IMDb_10              float64
# IMDb_100             float64
# IMDb_Votes             int64
# Metacritic            object
# Critic_Rating_RT     float64
# Critic_Reviews         int64
# Audience_Rating       object
# Audience_Reviews      object
# Letterboxd             int64
# Letterboxd_Votes      object
# Google_Score          object
# Streaming_On          object
# RT_URL                object
# imdbID                object
# Custom_Score         float64
# Awards_missing          bool
# dtype: object

# %%
a1["Genre"].nunique()
# Out:
# 228

# %%
a1["Genre"].value_counts().head(10)
# Out:
# Genre
# Drama                         56
# Drama, Romance                19
# Comedy, Drama                 14
# Drama, History                11
# Documentary                   10
# Drama, Crime                  10
# Comedy, Drama, Romance         9
# Animation, Family, Fantasy     6
# Crime, Drama, Thriller         6
# Crime, Drama                   6
# Name: count, dtype: int64

# %%
a1[num_cols].describe()
# Out:
#              Rank         Year  Flickmetrix_Score     IMDb_10    IMDb_100  \
# count  449.000000   449.000000         449.000000  449.000000  449.000000
# mean   225.000000  1994.151448          83.884187    7.969488   79.694878
# std    129.759393    25.683153           2.685102    0.359911    3.599106
# min      1.000000  1920.000000          80.000000    7.100000   71.000000
# 25%    113.000000  1976.000000          82.000000    7.700000   77.000000
# 50%    225.000000  2003.000000          83.000000    8.000000   80.000000
# 75%    337.000000  2015.000000          85.000000    8.200000   82.000000
# max    449.000000  2025.000000          93.000000    9.200000   92.000000
#
#          IMDb_Votes  Critic_Rating_RT  Critic_Reviews  Letterboxd  \
# count  4.490000e+02        449.000000      449.000000  449.000000
# mean   4.315229e+05         85.581292      122.926503   82.151448
# std    4.723575e+05          4.844751       67.931731    3.954457
# ...

# %%
a1.corr(numeric_only=True)
# Out:
#                        Rank      Year  Flickmetrix_Score   IMDb_10  IMDb_100  \
# Rank               1.000000  0.311242          -0.916902 -0.688085 -0.688085
# Year               0.311242  1.000000          -0.327566 -0.184472 -0.184472
# Flickmetrix_Score -0.916902 -0.327566           1.000000  0.653000  0.653000
# IMDb_10           -0.688085 -0.184472           0.653000  1.000000  1.000000
# IMDb_100          -0.688085 -0.184472           0.653000  1.000000  1.000000
# IMDb_Votes        -0.232216  0.102638           0.241927  0.653741  0.653741
# Critic_Rating_RT  -0.580103 -0.483183           0.700466  0.136416  0.136416
# Critic_Reviews     0.164202  0.594978          -0.113047 -0.052049 -0.052049
# Letterboxd        -0.609332 -0.049633           0.605828  0.674504  0.674504
# Custom_Score      -0.964430 -0.336219           0.957616  0.713435  0.713435
# Awards_missing          NaN       NaN                NaN       NaN       NaN
#
# ...

# %%
a1["Genre"].value_counts().head(10).plot(kind="bar",figsize=(10,5))
plt.title("Top 10 Genres")
plt.show()

# %%
a1["Year"].plot(kind="hist",bins=20,edgecolor="black")
plt.show()
