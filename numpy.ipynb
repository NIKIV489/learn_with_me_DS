# %% [markdown]
# <a href="https://colab.research.google.com/github/NIKIV489/learn_with_me_DS/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np

# %%
#array creation
a=np.array([1,23,45])
a1=np.arange(1,10,1)
a2=np.zeros((2,2))
a3=np.ones((2,8))
a4=np.linspace(1,5,6)
a5=np.random.random((1,1,4))
a6=np.random.randint(1,100,(5,5,5))
a7=np.shape(a6)
