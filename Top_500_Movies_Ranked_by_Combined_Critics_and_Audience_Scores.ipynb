# %%
import pandas as pd
a1=pd.read_csv("/content/Top 500 Movies Ranked by Combined Critics and Audience Scores.csv")

# %%
a1
# Out:
#      Rank                   Title  Year                   Genre  \
# 0       1           The Godfather  1972            Drama, Crime
# 1       2           Seven Samurai  1954           Action, Drama
# 2       3            12 Angry Men  1957                   Drama
# 3       4        Schindler's List  1993     Drama, History, War
# 4       5  The Godfather: Part II  1974            Drama, Crime
# ..    ...                     ...   ...                     ...
# 444   445                   Rocky  1976                   Drama
# 445   446          Phantom Thread  2017          Drama, Romance
# 446   447                Paterson  2016  Drama, Comedy, Romance
# 447   448                 Titanic  1997          Drama, Romance
# 448   449              Uncut Gems  2019  Drama, Thriller, Crime
#
#                       Director  \
# 0         Francis Ford Coppola
# 1               Akira Kurosawa
# 2                 Sidney Lumet
# 3             Steven Spielberg
# 4         Francis Ford Coppola
# ...

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               449 non-null    int64
#  1   Title              449 non-null    object
#  2   Year               449 non-null    int64
#  3   Genre              449 non-null    object
#  4   Director           449 non-null    object
#  5   Cast               448 non-null    object
#  6   Language           449 non-null    object
#  7   Plot               449 non-null    object
#  8   Awards             324 non-null    object
#  9   Production         329 non-null    object
#  10  Flickmetrix_Score  449 non-null    float64
#  11  IMDb_10            449 non-null    float64
#  12  IMDb_100           449 non-null    float64
#  13  IMDb_Votes         449 non-null    int64
#  14  Metacritic         436 non-null    float64
#  15  Critic_Rating_RT   449 non-null    float64
# ...

# %%
a1.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Year                   0
# Genre                  0
# Director               0
# Cast                   1
# Language               0
# Plot                   0
# Awards               125
# Production           120
# Flickmetrix_Score      0
# IMDb_10                0
# IMDb_100               0
# IMDb_Votes             0
# Metacritic            13
# Critic_Rating_RT       0
# Critic_Reviews         0
# Audience_Rating       48
# Audience_Reviews       7
# Letterboxd             0
# Letterboxd_Votes       1
# Google_Score           3
# Streaming_On          30
# RT_URL                17
# imdbID                 0
# Custom_Score           0
# dtype: int64

# %%
obj=["Cast","Awards","Production","Metacritic","Audience_Rating","Audience_Reviews","Letterboxd_Votes","Google_Score","Streaming_On","RT_URL"]

# %%
for col in obj:
    a1[col] = a1[col].fillna("unknown")
a1
# Out:
#      Rank                   Title  Year                   Genre  \
# 0       1           The Godfather  1972            Drama, Crime
# 1       2           Seven Samurai  1954           Action, Drama
# 2       3            12 Angry Men  1957                   Drama
# 3       4        Schindler's List  1993     Drama, History, War
# 4       5  The Godfather: Part II  1974            Drama, Crime
# ..    ...                     ...   ...                     ...
# 444   445                   Rocky  1976                   Drama
# 445   446          Phantom Thread  2017          Drama, Romance
# 446   447                Paterson  2016  Drama, Comedy, Romance
# 447   448                 Titanic  1997          Drama, Romance
# 448   449              Uncut Gems  2019  Drama, Thriller, Crime
#
#                       Director  \
# 0         Francis Ford Coppola
# 1               Akira Kurosawa
# 2                 Sidney Lumet
# 3             Steven Spielberg
# 4         Francis Ford Coppola
# ...

# %%
a1.head()
# Out:
#    Rank                   Title  Year                Genre  \
# 0     1           The Godfather  1972         Drama, Crime
# 1     2           Seven Samurai  1954        Action, Drama
# 2     3            12 Angry Men  1957                Drama
# 3     4        Schindler's List  1993  Drama, History, War
# 4     5  The Godfather: Part II  1974         Drama, Crime
#
#                Director                                               Cast  \
# 0  Francis Ford Coppola  Marlon Brando, Al Pacino, James Caan, Robert D...
# 1        Akira Kurosawa  Toshirō Mifune, Takashi Shimura, Yoshio Inaba,...
# 2          Sidney Lumet  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 3      Steven Spielberg  Liam Neeson, Ben Kingsley, Ralph Fiennes, Caro...
# 4  Francis Ford Coppola  Al Pacino, Robert Duvall, Diane Keaton, Robert...
#
#   Language                                               Plot  \
# 0       en  Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
a1.tail()
# Out:
#      Rank           Title  Year                   Genre  \
# 444   445           Rocky  1976                   Drama
# 445   446  Phantom Thread  2017          Drama, Romance
# 446   447        Paterson  2016  Drama, Comedy, Romance
# 447   448         Titanic  1997          Drama, Romance
# 448   449      Uncut Gems  2019  Drama, Thriller, Crime
#
#                       Director  \
# 444           John G. Avildsen
# 445       Paul Thomas Anderson
# 446               Jim Jarmusch
# 447              James Cameron
# 448  Josh Safdie, Benny Safdie
#
#                                                   Cast Language  \
# 444  Sylvester Stallone, Talia Shire, Burt Young, C...       en
# 445  Daniel Day-Lewis, Vicky Krieps, Lesley Manvill...       en
# 446  Adam Driver, Golshifteh Farahani, Nellie, Rizw...       en
# 447  Leonardo DiCaprio, Kate Winslet, Billy Zane, K...       en
# 448  Adam Sandler, LaKeith Stanfield, Julia Fox, Ke...       en
#
# ...

# %%
a1.isnull().sum()
# Out:
# Rank                 0
# Title                0
# Year                 0
# Genre                0
# Director             0
# Cast                 0
# Language             0
# Plot                 0
# Awards               0
# Production           0
# Flickmetrix_Score    0
# IMDb_10              0
# IMDb_100             0
# IMDb_Votes           0
# Metacritic           0
# Critic_Rating_RT     0
# Critic_Reviews       0
# Audience_Rating      0
# Audience_Reviews     0
# Letterboxd           0
# Letterboxd_Votes     0
# Google_Score         0
# Streaming_On         0
# RT_URL               0
# imdbID               0
# Custom_Score         0
# dtype: int64

# %%
print(a1["Audience_Rating"].dtype)
print(a1["Audience_Rating"].head())
# Out:
# object
# 0    95.0
# 1    94.0
# 2    94.0
# 3    94.0
# 4    94.0
# Name: Audience_Rating, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

a1["Audience_Rating"] = pd.to_numeric(
    a1["Audience_Rating"],
    errors="coerce"
)

print(a1["Audience_Rating"].notna().sum())

a1["Audience_Rating"].plot(kind="hist",bins=10,
    title="Audience Rating Distribution"
)

plt.xlabel("Audience Rating")
plt.ylabel("Frequency")
plt.show()
# Out:
# 401

# %%
a1["Audience_Rating"].dtype
a1["Audience_Rating"].head()
# Out:
# 0    95.0
# 1    94.0
# 2    94.0
# 3    94.0
# 4    94.0
# Name: Audience_Rating, dtype: float64

# %%
a1["Audience_Rating"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Audience_Rating'>

# %%
print(a1["Audience_Rating"].unique()[:10])
# Out:
# [95. 94. 92. 93. 88. 90. 91. 89. nan 85.]

# %%
a1["IMDb_10"].plot(kind="hist", bins=20)
plt.title("IMDb Rating Distribution")
# Out:
# Text(0.5, 1.0, 'IMDb Rating Distribution')

# %%
a1["Metacritic"].dtype
# Out:
# dtype('O')

# %%
a1[["Metacritic"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Metacritic  449 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
a1["Metacritic"].head(20)
# Out:
# 0     100.0
# 1      98.0
# 2      97.0
# 3      95.0
# 4      90.0
# 5     100.0
# 6      95.0
# 7      99.0
# 8      96.0
# 9      97.0
# 10     96.0
# 11     92.0
# 12     90.0
# 13     97.0
# 14    100.0
# 15     96.0
# 16     99.0
# 17     98.0
# 18     97.0
# 19     94.0
# Name: Metacritic, dtype: object

# %%
a1.select_dtypes(include="object").columns
# Out:
# Index(['Title', 'Genre', 'Director', 'Cast', 'Language', 'Plot', 'Awards',
#        'Production', 'Metacritic', 'Audience_Reviews', 'Letterboxd_Votes',
#        'Google_Score', 'Streaming_On', 'RT_URL', 'imdbID'],
#       dtype='object')

# %%
a1["Metacritic"] = pd.to_numeric(
    a1["Metacritic"],
    errors="coerce"
)

# %%
a1["Metacritic"].plot(kind="box")
plt.show()

# %%
rating_cols = [
    "IMDb_10",
    "IMDb_100",
    "Metacritic",
    "Critic_Rating_RT",
    "Audience_Rating",
    "Google_Score",
    "Custom_Score"
]

for col in rating_cols:
    print(col, a1[col].dtype)
# Out:
# IMDb_10 float64
# IMDb_100 float64
# Metacritic float64
# Critic_Rating_RT float64
# Audience_Rating float64
# Google_Score object
# Custom_Score float64

# %%
a1.describe(include="all")
# Out:
#               Rank                           Title         Year  Genre  \
# count   449.000000                             449   449.000000    449
# unique         NaN                             448          NaN    228
# top            NaN  All Quiet on the Western Front          NaN  Drama
# freq           NaN                               2          NaN     56
# mean    225.000000                             NaN  1994.151448    NaN
# std     129.759393                             NaN    25.683153    NaN
# min       1.000000                             NaN  1920.000000    NaN
# 25%     113.000000                             NaN  1976.000000    NaN
# 50%     225.000000                             NaN  2003.000000    NaN
# 75%     337.000000                             NaN  2015.000000    NaN
# max     449.000000                             NaN  2025.000000    NaN
#
#                 Director                                               Cast  \
# ...

# %%
a1.plot(
    x="IMDb_10",
    y="Metacritic",
    kind="scatter"
)
# Out:
# <Axes: xlabel='IMDb_10', ylabel='Metacritic'>

# %%
import seaborn as sns

sns.heatmap(
    a1.corr(numeric_only=True),
    annot=True
)
# Out:
# <Axes: >

# %%
a1["Language"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Language'>

# %%
a1["Genre"].value_counts().head(10).plot(kind="barh")
# Out:
# <Axes: ylabel='Genre'>

# %%
a1["Production"].value_counts().head(15).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
a1["Year"].value_counts().sort_index().plot(kind="line",marker="o")
# Out:
# <Axes: xlabel='Year'>

# %%
a1.nlargest(10, "IMDb_10")[["Title", "IMDb_10"]]
# Out:
#                                                  Title  IMDb_10
# 0                                        The Godfather      9.2
# 2                                         12 Angry Men      9.0
# 3                                     Schindler's List      9.0
# 4                               The Godfather: Part II      9.0
# 27       The Lord of the Rings: The Return of the King      9.0
# 6                                         Pulp Fiction      8.9
# 32   The Lord of the Rings: The Fellowship of the Ring      8.9
# 12                      The Good, the Bad and the Ugly      8.8
# 61               The Lord of the Rings: The Two Towers      8.8
# 102                                       Forrest Gump      8.8

# %%
a1.nlargest(10, "Metacritic")[["Title", "Metacritic"]]
# Out:
#                    Title  Metacritic
# 0          The Godfather       100.0
# 5            Rear Window       100.0
# 14            Casablanca       100.0
# 22    Lawrence of Arabia       100.0
# 28          Citizen Kane       100.0
# 38               Vertigo       100.0
# 188              Boyhood       100.0
# 7            City Lights        99.0
# 16   Singin' in the Rain        99.0
# 52         Touch of Evil        99.0

# %%
a1.groupby("Language")["IMDb_10"].mean()
# Out:
# Language
# ar    8.400000
# cn    8.100000
# da    7.966667
# de    8.075000
# en    7.987126
# es    7.828571
# fa    8.100000
# fr    7.850000
# ga    7.700000
# gl    7.500000
# he    8.000000
# hi    7.800000
# hu    7.400000
# id    8.200000
# it    8.054545
# ja    7.952381
# ko    7.925000
# lv    7.900000
# no    7.650000
# pl    7.450000
# pt    8.266667
# ro    7.900000
# ru    7.900000
# sv    7.950000
# te    7.800000
# tr    7.800000
# zh    7.850000
# Name: IMDb_10, dtype: float64

# %%
a1.groupby("Genre")["IMDb_10"].mean()
# Out:
# Genre
# Action, Adventure                       7.700
# Action, Adventure, Animation, Family    8.000
# Action, Adventure, Drama                7.800
# Action, Adventure, Science Fiction      7.675
# Action, Adventure, Thriller             7.800
#                                         ...
# War, History, Drama                     7.800
# War, History, Thriller, Drama           8.200
# Western                                 8.300
# Western, Crime, Drama                   7.600
# Western, Drama                          7.900
# Name: IMDb_10, Length: 228, dtype: float64

# %%
a1.describe(include="all")
# Out:
#               Rank                           Title         Year  Genre  \
# count   449.000000                             449   449.000000    449
# unique         NaN                             448          NaN    228
# top            NaN  All Quiet on the Western Front          NaN  Drama
# freq           NaN                               2          NaN     56
# mean    225.000000                             NaN  1994.151448    NaN
# std     129.759393                             NaN    25.683153    NaN
# min       1.000000                             NaN  1920.000000    NaN
# 25%     113.000000                             NaN  1976.000000    NaN
# 50%     225.000000                             NaN  2003.000000    NaN
# 75%     337.000000                             NaN  2015.000000    NaN
# max     449.000000                             NaN  2025.000000    NaN
#
#                 Director                                               Cast  \
# ...

# %%
a1.nunique()
# Out:
# Rank                 449
# Title                448
# Year                  93
# Genre                228
# Director             283
# Cast                 447
# Language              27
# Plot                 449
# Awards               302
# Production           124
# Flickmetrix_Score     14
# IMDb_10               21
# IMDb_100              21
# IMDb_Votes           449
# Metacritic            35
# Critic_Rating_RT      26
# Critic_Reviews       176
# Audience_Rating       26
# Audience_Reviews     443
# Letterboxd            13
# Letterboxd_Votes     449
# Google_Score          30
# Streaming_On          81
# RT_URL               433
# imdbID               449
# Custom_Score         104
# dtype: int64

# %%
a1["Genre"].value_counts()
# Out:
# Genre
# Drama                                   56
# Drama, Romance                          19
# Comedy, Drama                           14
# Drama, History                          11
# Documentary                             10
#                                         ..
# Animation, Drama, Adventure, Fantasy     1
# Music, Drama, Romance                    1
# Comedy, Drama, History                   1
# War, Drama, Thriller                     1
# Mystery, Horror, Romance                 1
# Name: count, Length: 228, dtype: int64

# %%
a1["Genre"].value_counts()
# Out:
# Genre
# Drama                                   56
# Drama, Romance                          19
# Comedy, Drama                           14
# Drama, History                          11
# Documentary                             10
#                                         ..
# Animation, Drama, Adventure, Fantasy     1
# Music, Drama, Romance                    1
# Comedy, Drama, History                   1
# War, Drama, Thriller                     1
# Mystery, Horror, Romance                 1
# Name: count, Length: 228, dtype: int64

# %%
a1.nsmallest(10, "Custom_Score")
# Out:
#      Rank                Title  Year                     Genre  \
# 448   449           Uncut Gems  2019    Drama, Thriller, Crime
# 447   448              Titanic  1997            Drama, Romance
# 444   445                Rocky  1976                     Drama
# 445   446       Phantom Thread  2017            Drama, Romance
# 446   447             Paterson  2016    Drama, Comedy, Romance
# 443   444           Cat People  1942  Mystery, Horror, Romance
# 439   440  The Death of Stalin  2017    Comedy, Drama, History
# 440   441          Son of Saul  2015      War, Drama, Thriller
# 441   442                    M  1931    Drama, Thriller, Crime
# 442   443    Kill Bill: Vol. 1  2003             Action, Crime
#
#                       Director  \
# 448  Josh Safdie, Benny Safdie
# 447              James Cameron
# 444           John G. Avildsen
# 445       Paul Thomas Anderson
# 446               Jim Jarmusch
# 443           Jacques Tourneur
# 439           Armando Iannucci
# ...
