# %%
import pandas as pd

# %%
i=pd.read_csv("/content/ipl_matches_2026.csv")

# %%
i.head()
# Out:
#          date  season            city  \
# 0  2026-03-28    2026       Bengaluru
# 1  2026-03-29    2026          Mumbai
# 2  2026-03-30    2026        Guwahati
# 3  2026-03-31    2026  New Chandigarh
# 4  2026-04-01    2026         Lucknow
#
#                                                venue                  team1  \
# 0                   M Chinnaswamy Stadium, Bengaluru    Sunrisers Hyderabad
# 1                           Wankhede Stadium, Mumbai  Kolkata Knight Riders
# 2                Barsapara Cricket Stadium, Guwahati    Chennai Super Kings
# 3  Maharaja Yadavindra Singh International Cricke...         Gujarat Titans
# 4  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   Lucknow Super Giants
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
# 1               Mumbai Indians               Mumbai Indians         field
# 2             Rajasthan Royals             Rajasthan Royals         field
# 3                 Punjab Kings                 Punjab Kings         field
# 4               Delhi Capitals               Delhi Capitals         field
#
#    team1_runs  team1_wickets  ...  win_by_wickets  player_of_match  \
# 0         201              9  ...               6         JA Duffy
# 1         220              4  ...               6        SN Thakur
# 2         127             10  ...               8         N Burger
# 3         162              6  ...               3       C Connolly
# 4         141             10  ...               6     Sameer Rizvi
#
#      match_referee               umpire1               umpire2  \
# 0        J Srinath         J Madanagopal             UV Gandhe
# 1     Shakti Singh    Anish Sahasrabudhe  MV Saidharshan Kumar
# 2  V Narayan Kutty       HDPK Dharmasena          M Krishnadas
# 3    Prakash Bhatt  Abhijit Bhattacharya               A Totre
# 4        J Srinath              R Pandit             UV Gandhe
#
#                tv_umpire  reserve_umpire overs_limit  \
# 0               R Pandit       A Bengeri          20
# 1            Nitin Menon    Vinod Seshan          20
# 2              VK Sharma  K Swaroopanand          20
# 3  KN Ananthapadmanabhan         P Joshi          20
# 4          J Madanagopal       A Bengeri          20
#
#                                        team1_players  \
# 0  TM Head, Abhishek Sharma, Ishan Kishan, Nithis...
# 1  Kartik Tyagi, AM Rahane, FH Allen, C Green, A ...
# 2  SV Samson, RD Gaikwad, A Mhatre, MW Short, SN ...
# 3  M Prasidh Krishna, B Sai Sudharsan, Shubman Gi...
# 4  MR Marsh, RR Pant, AK Markram, A Badoni, N Poo...
#
#                                        team2_players
# 0  JA Duffy, PD Salt, V Kohli, D Padikkal, RM Pat...
# 1  JJ Bumrah, RD Rickelton, RG Sharma, SA Yadav, ...
# 2  YBK Jaiswal, V Suryavanshi, Dhruv Jurel, R Par...
# 3  YS Chahal, Priyansh Arya, P Simran Singh, C Co...
# 4  T Natarajan, KL Rahul, P Nissanka, N Rana, Sam...
#
# [5 rows x 25 columns]

# %%
i.shape
# Out:
# (74, 25)

# %%
i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             74 non-null     object
#  1   season           74 non-null     int64
#  2   city             74 non-null     object
#  3   venue            74 non-null     object
#  4   team1            74 non-null     object
#  5   team2            74 non-null     object
#  6   toss_winner      74 non-null     object
#  7   toss_decision    74 non-null     object
#  8   team1_runs       74 non-null     int64
#  9   team1_wickets    74 non-null     int64
#  10  team2_runs       74 non-null     int64
#  11  team2_wickets    74 non-null     int64
#  12  winner           72 non-null     object
#  13  result_type      74 non-null     object
#  14  win_by_runs      74 non-null     int64
#  15  win_by_wickets   74 non-null     int64
#  16  player_of_match  73 non-null     object
#  17  match_referee    74 non-null     object
#  18  umpire1          74 non-null     object
#  19  umpire2          74 non-null     object
#  20  tv_umpire        74 non-null     object
#  21  reserve_umpire   74 non-null     object
#  22  overs_limit      74 non-null     int64
#  23  team1_players    74 non-null     object
#  24  team2_players    74 non-null     object
# dtypes: int64(8), object(17)
# memory usage: 14.6+ KB

# %%
i.describe()
# Out:
#        season  team1_runs  team1_wickets  team2_runs  team2_wickets  \
# count    74.0   74.000000      74.000000   74.000000      74.000000
# mean   2026.0  193.081081       6.121622  177.932432       5.797297
# std       0.0   41.367632       2.287265   42.140122       2.754721
# min    2026.0   25.000000       2.000000    0.000000       0.000000
# 25%    2026.0  162.250000       4.000000  160.000000       4.000000
# 50%    2026.0  200.500000       6.000000  181.500000       5.000000
# 75%    2026.0  221.500000       8.000000  204.750000       8.000000
# max    2026.0  264.000000      10.000000  265.000000      10.000000
#
#        win_by_runs  win_by_wickets  overs_limit
# count    74.000000       74.000000         74.0
# mean     16.635135        3.513514         20.0
# std      28.195780        3.079954          0.0
# min       0.000000        0.000000         20.0
# 25%       0.000000        0.000000         20.0
# 50%       0.000000        4.500000         20.0
# 75%      28.500000        6.000000         20.0
# max     103.000000        9.000000         20.0

# %%
#missing values
i.isnull().sum()
# Out:
# date               0
# season             0
# city               0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# team1_runs         0
# team1_wickets      0
# team2_runs         0
# team2_wickets      0
# winner             2
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    1
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
i.isna().sum()
# Out:
# date               0
# season             0
# city               0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# team1_runs         0
# team1_wickets      0
# team2_runs         0
# team2_wickets      0
# winner             2
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    1
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
i.duplicated().sum()
# Out:
# np.int64(0)

# %%
i["season"]

# %%
sns.countplot(x=i["season"])      # Good
sns.countplot(data=i, x="season") # Best for DataFrames
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %%
tm = pd.concat([i["team1"], i["team2"]])
tm.value_counts()
# Out:
# Gujarat Titans                 17
# Rajasthan Royals               16
# Royal Challengers Bengaluru    16
# Sunrisers Hyderabad            15
# Kolkata Knight Riders          14
# Chennai Super Kings            14
# Lucknow Super Giants           14
# Mumbai Indians                 14
# Punjab Kings                   14
# Delhi Capitals                 14
# Name: count, dtype: int64

# %%
i["winner"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='winner'>

# %%
i["toss_winner"].value_counts().plot(kind="line",marker="d")
# Out:
# <Axes: xlabel='toss_winner'>

# %%
i["toss_decision"].value_counts().plot(kind="line",marker="d")
# Out:
# <Axes: xlabel='toss_decision'>

# %%
i["player_of_match"].value_counts().plot(
    kind="line",
    marker="d",
    figsize=(10, 10)
)
# Out:
# <Axes: xlabel='player_of_match'>

# %%
i['team1_wickets'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='team1_wickets'>

# %%
i.sort_values(by="team1_wickets")
# Out:
#           date  season       city  \
# 11  2026-04-06    2026    Kolkata
# 16  2026-04-11    2026    Chennai
# 30  2026-04-21    2026  Hyderabad
# 34  2026-04-25    2026      Delhi
# 59  2026-05-16    2026    Kolkata
# ..         ...     ...        ...
# 4   2026-04-01    2026    Lucknow
# 22  2026-04-15    2026  Bengaluru
# 24  2026-04-17    2026  Ahmedabad
# 41  2026-04-30    2026  Ahmedabad
# 38  2026-04-27    2026      Delhi
#
#                                                 venue  \
# 11                              Eden Gardens, Kolkata
# 16           MA Chidambaram Stadium, Chepauk, Chennai
# 30  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 34                        Arun Jaitley Stadium, Delhi
# 59                              Eden Gardens, Kolkata
# ..                                                ...
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 22                   M Chinnaswamy Stadium, Bengaluru
# 24                   Narendra Modi Stadium, Ahmedabad
# 41                   Narendra Modi Stadium, Ahmedabad
# 38                        Arun Jaitley Stadium, Delhi
#
#                           team1                        team2  \
# 11        Kolkata Knight Riders                 Punjab Kings
# 16          Chennai Super Kings               Delhi Capitals
# 30          Sunrisers Hyderabad               Delhi Capitals
# 34               Delhi Capitals                 Punjab Kings
# 59        Kolkata Knight Riders               Gujarat Titans
# ..                          ...                          ...
# 4          Lucknow Super Giants               Delhi Capitals
# 22         Lucknow Super Giants  Royal Challengers Bengaluru
# 24        Kolkata Knight Riders               Gujarat Titans
# 41  Royal Challengers Bengaluru               Gujarat Titans
# 38               Delhi Capitals  Royal Challengers Bengaluru
#
#                     toss_winner toss_decision  team1_runs  team1_wickets  ...  \
# 11        Kolkata Knight Riders           bat          25              2  ...
# 16               Delhi Capitals         field         212              2  ...
# 30               Delhi Capitals         field         242              2  ...
# 34               Delhi Capitals           bat         264              2  ...
# 59               Gujarat Titans         field         247              2  ...
# ..                          ...           ...         ...            ...  ...
# 4                Delhi Capitals         field         141             10  ...
# 22  Royal Challengers Bengaluru         field         146             10  ...
# 24        Kolkata Knight Riders           bat         180             10  ...
# 41               Gujarat Titans         field         155             10  ...
# 38  Royal Challengers Bengaluru         field          75             10  ...
#
#     win_by_wickets  player_of_match    match_referee               umpire1  \
# 11               0              NaN        J Srinath             A Bengeri
# 16               0        SV Samson     Shakti Singh  MV Saidharshan Kumar
# 30               0  Abhishek Sharma     Shakti Singh    Anish Sahasrabudhe
# 34               6         KL Rahul  V Narayan Kutty              AK Argal
# 59               0        SP Narine           R Seth        K Swaroopanand
# ..             ...              ...              ...                   ...
# 4                6     Sameer Rizvi        J Srinath              R Pandit
# 22               5     JR Hazlewood    Prakash Bhatt          AT Holdstock
# 24               5     Shubman Gill        J Srinath              R Pandit
# 41               4        JO Holder      IR Siddiqui          AT Holdstock
# 38               9     JR Hazlewood  V Narayan Kutty              AK Argal
#
#                   umpire2              tv_umpire        reserve_umpire  \
# 11          J Madanagopal               R Pandit             UV Gandhe
# 16           Vinod Seshan            Nitin Menon    Anish Sahasrabudhe
# 30           Vinod Seshan           AT Holdstock  MV Saidharshan Kumar
# 34              VK Sharma         K Swaroopanand            HAS Khalid
# 59              VK Sharma            SJ Nogajski              AK Argal
# ..                    ...                    ...                   ...
# 4               UV Gandhe          J Madanagopal             A Bengeri
# 22          Bhavesh Patel  KN Ananthapadmanabhan  Abhijit Bhattacharya
# 24              UV Gandhe          J Madanagopal              K Kelkar
# 41  KN Ananthapadmanabhan   Abhijit Bhattacharya               P Joshi
# 38            SJ Nogajski           M Krishnadas            HAS Khalid
#
#    overs_limit                                      team1_players  \
# 11          20  AM Rahane, FH Allen, C Green, A Raghuvanshi, R...
# 16          20  AJ Hosein, SV Samson, RD Gaikwad, A Mhatre, S ...
# 30          20  D Madushanka, Abhishek Sharma, TM Head, Ishan ...
# 34          20  Auqib Nabi, V Nigam, P Nissanka, KL Rahul, N R...
# 59          20  M Pathirana, AM Rahane, FH Allen, A Raghuvansh...
# ..         ...                                                ...
# 4           20  MR Marsh, RR Pant, AK Markram, A Badoni, N Poo...
# 22          20  MR Marsh, AK Markram, RR Pant, N Pooran, A Bad...
# 24          20  CV Varun, TL Seifert, AM Rahane, A Raghuvanshi...
# 41          20  JG Bethell, V Kohli, D Padikkal, RM Patidar, J...
# 38          20  SU Parakh, KL Rahul, N Rana, Sameer Rizvi, T S...
#
#                                         team2_players
# 11  SS Iyer, P Simran Singh, N Wadhera, C Connolly...
# 16  Mukesh Kumar, P Nissanka, KL Rahul, Sameer Riz...
# 30  Mukesh Kumar, P Nissanka, KL Rahul, N Rana, Sa...
# 34  YS Chahal, Priyansh Arya, P Simran Singh, C Co...
# 59  Mohammed Siraj, B Sai Sudharsan, Shubman Gill,...
# ..                                                ...
# 4   T Natarajan, KL Rahul, P Nissanka, N Rana, Sam...
# 22  Suyash Sharma, PD Salt, V Kohli, D Padikkal, R...
# 24  M Prasidh Krishna, B Sai Sudharsan, Shubman Gi...
# 41  Mohammed Siraj, B Sai Sudharsan, Shubman Gill,...
# 38  Suyash Sharma, JG Bethell, V Kohli, D Padikkal...
#
# [74 rows x 25 columns]

# %%
i['player_of_match'].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='player_of_match'>

# %%
i[["team1","team2"]].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='team1,team2'>

# %%
vw=i.groupby(["venue","winner"]).size().sort_values(ascending=False)
vw
# Out:
# venue                                                                    winner
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     Sunrisers Hyderabad            5
# Narendra Modi Stadium, Ahmedabad                                         Gujarat Titans                 5
# M Chinnaswamy Stadium, Bengaluru                                         Royal Challengers Bengaluru    4
# MA Chidambaram Stadium, Chepauk, Chennai                                 Chennai Super Kings            4
# Eden Gardens, Kolkata                                                    Kolkata Knight Riders          3
# Barsapara Cricket Stadium, Guwahati                                      Rajasthan Royals               3
# Maharaja Yadavindra Singh International Cricket Stadium, New Chandigarh  Punjab Kings                   3
#                                                                          Rajasthan Royals               2
# Himachal Pradesh Cricket Association Stadium, Dharamsala                 Royal Challengers Bengaluru    2
# Shaheed Veer Narayan Singh International Stadium, Raipur                 Royal Challengers Bengaluru    2
# Arun Jaitley Stadium, Delhi                                              Delhi Capitals                 2
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    Lucknow Super Giants           2
# Wankhede Stadium, Mumbai                                                 Mumbai Indians                 2
# Arun Jaitley Stadium, Delhi                                              Gujarat Titans                 1
# Eden Gardens, Kolkata                                                    Delhi Capitals                 1
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    Rajasthan Royals               1
#                                                                          Punjab Kings                   1
#                                                                          Gujarat Titans                 1
#                                                                          Delhi Capitals                 1
# Arun Jaitley Stadium, Delhi                                              Kolkata Knight Riders          1
#                                                                          Punjab Kings                   1
#                                                                          Royal Challengers Bengaluru    1
#                                                                          Chennai Super Kings            1
# M Chinnaswamy Stadium, Bengaluru                                         Delhi Capitals                 1
# Himachal Pradesh Cricket Association Stadium, Dharamsala                 Delhi Capitals                 1
# MA Chidambaram Stadium, Chepauk, Chennai                                 Gujarat Titans                 1
# Maharaja Yadavindra Singh International Cricket Stadium, New Chandigarh  Gujarat Titans                 1
# Eden Gardens, Kolkata                                                    Sunrisers Hyderabad            1
# Himachal Pradesh Cricket Association Stadium, Dharamsala                 Mumbai Indians                 1
# Eden Gardens, Kolkata                                                    Lucknow Super Giants           1
# Narendra Modi Stadium, Ahmedabad                                         Mumbai Indians                 1
# MA Chidambaram Stadium, Chepauk, Chennai                                 Punjab Kings                   1
#                                                                          Sunrisers Hyderabad            1
# Narendra Modi Stadium, Ahmedabad                                         Rajasthan Royals               1
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     Lucknow Super Giants           1
# Sawai Mansingh Stadium, Jaipur                                           Delhi Capitals                 1
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     Kolkata Knight Riders          1
# Narendra Modi Stadium, Ahmedabad                                         Royal Challengers Bengaluru    1
# Sawai Mansingh Stadium, Jaipur                                           Rajasthan Royals               1
#                                                                          Gujarat Titans                 1
#                                                                          Sunrisers Hyderabad            1
# Wankhede Stadium, Mumbai                                                 Chennai Super Kings            1
#                                                                          Punjab Kings                   1
#                                                                          Rajasthan Royals               1
#                                                                          Royal Challengers Bengaluru    1
#                                                                          Sunrisers Hyderabad            1
# dtype: int64

# %%
i.describe()
# Out:
#        season  team1_runs  team1_wickets  team2_runs  team2_wickets  \
# count    74.0   74.000000      74.000000   74.000000      74.000000
# mean   2026.0  193.081081       6.121622  177.932432       5.797297
# std       0.0   41.367632       2.287265   42.140122       2.754721
# min    2026.0   25.000000       2.000000    0.000000       0.000000
# 25%    2026.0  162.250000       4.000000  160.000000       4.000000
# 50%    2026.0  200.500000       6.000000  181.500000       5.000000
# 75%    2026.0  221.500000       8.000000  204.750000       8.000000
# max    2026.0  264.000000      10.000000  265.000000      10.000000
#
#        win_by_runs  win_by_wickets  overs_limit
# count    74.000000       74.000000         74.0
# mean     16.635135        3.513514         20.0
# std      28.195780        3.079954          0.0
# min       0.000000        0.000000         20.0
# 25%       0.000000        0.000000         20.0
# 50%       0.000000        4.500000         20.0
# 75%      28.500000        6.000000         20.0
# max     103.000000        9.000000         20.0

# %%
i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             74 non-null     object
#  1   season           74 non-null     int64
#  2   city             74 non-null     object
#  3   venue            74 non-null     object
#  4   team1            74 non-null     object
#  5   team2            74 non-null     object
#  6   toss_winner      74 non-null     object
#  7   toss_decision    74 non-null     object
#  8   team1_runs       74 non-null     int64
#  9   team1_wickets    74 non-null     int64
#  10  team2_runs       74 non-null     int64
#  11  team2_wickets    74 non-null     int64
#  12  winner           72 non-null     object
#  13  result_type      74 non-null     object
#  14  win_by_runs      74 non-null     int64
#  15  win_by_wickets   74 non-null     int64
#  16  player_of_match  73 non-null     object
#  17  match_referee    74 non-null     object
#  18  umpire1          74 non-null     object
#  19  umpire2          74 non-null     object
#  20  tv_umpire        74 non-null     object
#  21  reserve_umpire   74 non-null     object
#  22  overs_limit      74 non-null     int64
#  23  team1_players    74 non-null     object
#  24  team2_players    74 non-null     object
# dtypes: int64(8), object(17)
# memory usage: 14.6+ KB

# %%
e=i[i["result_type"] != "complete"].value_counts()
e
# Out:
# Series([], Name: count, dtype: int64)

# %%
i.loc[i["result_type"] != "complete", "result_type"]
# Out:
# 11    no result
# 36          tie
# Name: result_type, dtype: object

# %%
i.head()
# Out:
#          date  season            city  \
# 0  2026-03-28    2026       Bengaluru
# 1  2026-03-29    2026          Mumbai
# 2  2026-03-30    2026        Guwahati
# 3  2026-03-31    2026  New Chandigarh
# 4  2026-04-01    2026         Lucknow
#
#                                                venue                  team1  \
# 0                   M Chinnaswamy Stadium, Bengaluru    Sunrisers Hyderabad
# 1                           Wankhede Stadium, Mumbai  Kolkata Knight Riders
# 2                Barsapara Cricket Stadium, Guwahati    Chennai Super Kings
# 3  Maharaja Yadavindra Singh International Cricke...         Gujarat Titans
# 4  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   Lucknow Super Giants
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
# 1               Mumbai Indians               Mumbai Indians         field
# 2             Rajasthan Royals             Rajasthan Royals         field
# 3                 Punjab Kings                 Punjab Kings         field
# 4               Delhi Capitals               Delhi Capitals         field
#
#    team1_runs  team1_wickets  ...  win_by_wickets  player_of_match  \
# 0         201              9  ...               6         JA Duffy
# 1         220              4  ...               6        SN Thakur
# 2         127             10  ...               8         N Burger
# 3         162              6  ...               3       C Connolly
# 4         141             10  ...               6     Sameer Rizvi
#
#      match_referee               umpire1               umpire2  \
# 0        J Srinath         J Madanagopal             UV Gandhe
# 1     Shakti Singh    Anish Sahasrabudhe  MV Saidharshan Kumar
# 2  V Narayan Kutty       HDPK Dharmasena          M Krishnadas
# 3    Prakash Bhatt  Abhijit Bhattacharya               A Totre
# 4        J Srinath              R Pandit             UV Gandhe
#
#                tv_umpire  reserve_umpire overs_limit  \
# 0               R Pandit       A Bengeri          20
# 1            Nitin Menon    Vinod Seshan          20
# 2              VK Sharma  K Swaroopanand          20
# 3  KN Ananthapadmanabhan         P Joshi          20
# 4          J Madanagopal       A Bengeri          20
#
#                                        team1_players  \
# 0  TM Head, Abhishek Sharma, Ishan Kishan, Nithis...
# 1  Kartik Tyagi, AM Rahane, FH Allen, C Green, A ...
# 2  SV Samson, RD Gaikwad, A Mhatre, MW Short, SN ...
# 3  M Prasidh Krishna, B Sai Sudharsan, Shubman Gi...
# 4  MR Marsh, RR Pant, AK Markram, A Badoni, N Poo...
#
#                                        team2_players
# 0  JA Duffy, PD Salt, V Kohli, D Padikkal, RM Pat...
# 1  JJ Bumrah, RD Rickelton, RG Sharma, SA Yadav, ...
# 2  YBK Jaiswal, V Suryavanshi, Dhruv Jurel, R Par...
# 3  YS Chahal, Priyansh Arya, P Simran Singh, C Co...
# 4  T Natarajan, KL Rahul, P Nissanka, N Rana, Sam...
#
# [5 rows x 25 columns]

# %%
tm = i[i["result_type"] == "tie"]
tm
# Out:
#           date  season     city  \
# 36  2026-04-26    2026  Lucknow
#
#                                                 venue                  team1  \
# 36  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Kolkata Knight Riders
#
#                    team2           toss_winner toss_decision  team1_runs  \
# 36  Lucknow Super Giants  Lucknow Super Giants         field         159
#
#     team1_wickets  ...  win_by_wickets  player_of_match match_referee  \
# 36              7  ...               0         RK Singh     J Srinath
#
#       umpire1   umpire2  tv_umpire reserve_umpire overs_limit  \
# 36  A Bengeri  K Kelkar   R Pandit      Amit Rana          20
#
#                                         team1_players  \
# 36  CV Varun, AM Rahane, TL Seifert, A Raghuvanshi...
#
#                                         team2_players
# 36  Mohsin Khan, AK Markram, MR Marsh, RR Pant, N ...
#
# [1 rows x 25 columns]

# %%
i[["team1","team2","venue"]]
# Out:
#                           team1                        team2  \
# 0           Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1         Kolkata Knight Riders               Mumbai Indians
# 2           Chennai Super Kings             Rajasthan Royals
# 3                Gujarat Titans                 Punjab Kings
# 4          Lucknow Super Giants               Delhi Capitals
# ..                          ...                          ...
# 69               Delhi Capitals        Kolkata Knight Riders
# 70  Royal Challengers Bengaluru               Gujarat Titans
# 71             Rajasthan Royals          Sunrisers Hyderabad
# 72             Rajasthan Royals               Gujarat Titans
# 73               Gujarat Titans  Royal Challengers Bengaluru
#
#                                                 venue
# 0                    M Chinnaswamy Stadium, Bengaluru
# 1                            Wankhede Stadium, Mumbai
# 2                 Barsapara Cricket Stadium, Guwahati
# 3   Maharaja Yadavindra Singh International Cricke...
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# ..                                                ...
# 69                              Eden Gardens, Kolkata
# 70  Himachal Pradesh Cricket Association Stadium, ...
# 71  Maharaja Yadavindra Singh International Cricke...
# 72  Maharaja Yadavindra Singh International Cricke...
# 73                   Narendra Modi Stadium, Ahmedabad
#
# [74 rows x 3 columns]

# %%
i["venue"].value_counts()
# Out:
# venue
# Narendra Modi Stadium, Ahmedabad                                           8
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow      7
# MA Chidambaram Stadium, Chepauk, Chennai                                   7
# Eden Gardens, Kolkata                                                      7
# Wankhede Stadium, Mumbai                                                   7
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                       7
# Arun Jaitley Stadium, Delhi                                                7
# Maharaja Yadavindra Singh International Cricket Stadium, New Chandigarh    6
# M Chinnaswamy Stadium, Bengaluru                                           5
# Himachal Pradesh Cricket Association Stadium, Dharamsala                   4
# Sawai Mansingh Stadium, Jaipur                                             4
# Barsapara Cricket Stadium, Guwahati                                        3
# Shaheed Veer Narayan Singh International Stadium, Raipur                   2
# Name: count, dtype: int64

# %%
i["city"].value_counts()
# Out:
# city
# Ahmedabad         8
# Lucknow           7
# Chennai           7
# Kolkata           7
# Mumbai            7
# Hyderabad         7
# Delhi             7
# New Chandigarh    6
# Bengaluru         5
# Dharamsala        4
# Jaipur            4
# Guwahati          3
# Raipur            2
# Name: count, dtype: int64

# %%
i["city"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
i.groupby(["season","winner"]).size().sort_values(ascending=False).head(10)
# Out:
# season  winner
# 2026    Royal Challengers Bengaluru    11
#         Gujarat Titans                 10
#         Rajasthan Royals                9
#         Sunrisers Hyderabad             9
#         Punjab Kings                    7
#         Delhi Capitals                  7
#         Chennai Super Kings             6
#         Kolkata Knight Riders           5
#         Mumbai Indians                  4
#         Lucknow Super Giants            4
# dtype: int64

# %%
i.groupby("team1")["team1_runs"].max().sort_values(ascending=False)
# Out:
# team1
# Delhi Capitals                 264
# Sunrisers Hyderabad            255
# Royal Challengers Bengaluru    254
# Punjab Kings                   254
# Kolkata Knight Riders          247
# Mumbai Indians                 243
# Rajasthan Royals               243
# Gujarat Titans                 229
# Lucknow Super Giants           228
# Chennai Super Kings            212
# Name: team1_runs, dtype: int64

# %%
mp=pd.concat([i["team1"],i["team2"]]).value_counts()
mp
# Out:
# Gujarat Titans                 17
# Rajasthan Royals               16
# Royal Challengers Bengaluru    16
# Sunrisers Hyderabad            15
# Kolkata Knight Riders          14
# Chennai Super Kings            14
# Lucknow Super Giants           14
# Mumbai Indians                 14
# Punjab Kings                   14
# Delhi Capitals                 14
# Name: count, dtype: int64

# %%
wi=i["winner"].value_counts()
wi
# Out:
# winner
# Royal Challengers Bengaluru    11
# Gujarat Titans                 10
# Sunrisers Hyderabad             9
# Rajasthan Royals                9
# Delhi Capitals                  7
# Punjab Kings                    7
# Chennai Super Kings             6
# Kolkata Knight Riders           5
# Mumbai Indians                  4
# Lucknow Super Giants            4
# Name: count, dtype: int64

# %%
e=(wi/mp)*100
e.sort_values(ascending=False)
e
# Out:
# Chennai Super Kings            42.857143
# Delhi Capitals                 50.000000
# Gujarat Titans                 58.823529
# Kolkata Knight Riders          35.714286
# Lucknow Super Giants           28.571429
# Mumbai Indians                 28.571429
# Punjab Kings                   50.000000
# Rajasthan Royals               56.250000
# Royal Challengers Bengaluru    68.750000
# Sunrisers Hyderabad            60.000000
# Name: count, dtype: float64

# %%
e = (wi / mp) * 100
e = e.round(2)
e.sort_values(ascending=False,inplace=True)
e
# Out:
# Royal Challengers Bengaluru    68.75
# Sunrisers Hyderabad            60.00
# Gujarat Titans                 58.82
# Rajasthan Royals               56.25
# Punjab Kings                   50.00
# Delhi Capitals                 50.00
# Chennai Super Kings            42.86
# Kolkata Knight Riders          35.71
# Mumbai Indians                 28.57
# Lucknow Super Giants           28.57
# Name: count, dtype: float64

# %%
e.sort_values().plot(
    kind="barh",
    figsize=(8, 5),
    title="Win Percentage of Teams"
)
# Out:
# <Axes: title={'center': 'Win Percentage of Teams'}>

# %%
e.sort_values().plot(
    kind="pie",
    figsize=(8, 5),
    title="Win Percentage of Teams"
)
# Out:
# <Axes: title={'center': 'Win Percentage of Teams'}, ylabel='count'>

# %%
e.sort_values().plot(
    kind="pie",
    figsize=(8, 5),
    title="Win Percentage of Teams"
)
# Out:
# <Axes: title={'center': 'Win Percentage of Teams'}, ylabel='count'>

# %%
e.sort_values().plot(
    kind="hist",
    figsize=(8, 5),
    title="Win Percentage of Teams"
)
# Out:
# <Axes: title={'center': 'Win Percentage of Teams'}, ylabel='Frequency'>

# %%
#Exploratory data analysis

#1 used to analysze the pattern and investigate the data set than data visualization
#2 duscover the pattern,assumptions and trends help of statisticals summary and graphical representations
#3 EDA appproach to analyze the data using the visual technique

#sample vs population
#1 population - the data to be olllected
#2 sample - a portion of population

#types of data
#1- Qualitative
#2 -Quantitative

#norminal - category not a order
#ordinal -natural order-rank
#binary - two possible values

#discrete-counting the individual units and separate(counting) ==> does not depend not on the previous data
#continous-data often show trends in data over time.(tempearture,stock prices) ==> depends on the previous data

# %%
'''
#Statiscs--branch of applied mathematics focused on analyze,collection,analysis,organisation,interpretation,presentation of data
  #1.descriptive--describe
  #2.inferential--insights--findings(ml),conclusion,test hypothesis based on the larger population based on sample data


#1 ====Descriptive Statistics====
#i-measure of central tendency -mean,median,mode
#ii-measure of dispersion/spread/deviation - range,IQR,Standard DEviation,variance
#iii-measure of frequency
#iv -measure of distribution-kurtosis,skewness

#summarizing and organizing the data

#i-measure of central tendency

      #1 -MEAN
          #-->x=sum of all /number of data

          #x=sample mean
          #mu=population mean

      #2 -MEDIAN
        #arrange in ascending order
        #divded the data in two equal parts
        #median will be center value value if it is odd
        #median will be average if it is in even number

      #3 -MODE
        #most appearing mode or maximum appear on the data
        #1 - bimodal
        #2 - Trimodal
        #3 - multimodal

# ii measure of spread/dispresion
   #hhighest-lowest
   #1 Quartile
      #IQR Range- divided by 4
      #Intertertile -divided by 3
      #interQuintile-divide by 5

  #2 standard deviation -how much data is disprese from the mean ,spread the value awya from the mean
     #low sd==tightly clustered towards the mean
     #high sd == data points are widely spread from the mean
      #
     # \(\sigma =\sqrt{\frac{\sum (x_{i}-\mu )^{2}}{N}}\)

  #3 Variance
     # average of squared deviations

#iii frequency

     #frequence of an event
     #n represents the number of  event occured in the experiment
     #represent in histogram

"""

# %%
import pandas as pd

# %%
ai=pd.read_csv("/content/ai-impact-jobs-layoff-risk-dataset.csv")
ai
# Out:
#        Age Education_Level  Years_of_Experience       Industry  \
# 0       59        Master's                    6        Finance
# 1       44        Master's                   14  Manufacturing
# 2       36      Bachelor's                    7         Retail
# 3       27      Bachelor's                    6        Finance
# 4       49     High School                   12        Finance
# ...    ...             ...                  ...            ...
# 19995   56      Bachelor's                   10         Retail
# 19996   43      Bachelor's                    9  Manufacturing
# 19997   28     High School                    7        Telecom
# 19998   46      Bachelor's                    3  Manufacturing
# 19999   36      Bachelor's                    5         Retail
#
#                     Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0                 Accountant       Medium     Entry                       84
# 1      Production Supervisor        Small     Entry                       30
# 2              Store Manager       Medium    Senior                       12
# 3                    Auditor        Large     Entry                       90
# 4                    Auditor        Small     Entry                       49
# ...                      ...          ...       ...                      ...
# 19995        Sales Associate        Small     Entry                       29
# 19996  Production Supervisor       Medium     Entry                       87
# 19997     Support Specialist       Medium     Entry                       91
# 19998       Quality Engineer       Medium    Senior                       76
# 19999          Store Manager       Medium       Mid                       45
#
#        Creativity_Requirement  Human_Interaction_Level AI_Adoption_Level  \
# 0                          21                       94            Medium
# 1                          84                       68               Low
# 2                          86                       71               Low
# 3                          18                       21            Medium
# 4                          52                       72            Medium
# ...                       ...                      ...               ...
# 19995                      62                       44               Low
# 19996                      20                       20              High
# 19997                       2                       49            Medium
# 19998                      40                       89            Medium
# 19999                      65                       75               Low
#
#        Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# 0                            5                        7
# 1                            2                        2
# 2                            0                        1
# 3                            3                       10
# 4                            5                       13
# ...                        ...                      ...
# 19995                        0                        4
# 19996                        9                       23
# 19997                        2                       14
# 19998                        3                       13
# 19999                        1                        0
#
#        Tasks_Automated_Percentage  AI_Training_Hours Layoff_Risk
# 0                              40                 26        High
# 1                              14                  9         Low
# 2                               6                  3         Low
# 3                              67                 26        High
# 4                              26                 19      Medium
# ...                           ...                ...         ...
# 19995                          16                  0      Medium
# 19996                          77                 67        High
# 19997                          55                 10        High
# 19998                          66                  5      Medium
# 19999                          30                  8      Medium
#
# [20000 rows x 16 columns]

# %%
ai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  object
#  2   Years_of_Experience         20000 non-null  int64
#  3   Industry                    20000 non-null  object
#  4   Job_Role                    20000 non-null  object
#  5   Company_Size                20000 non-null  object
#  6   Job_Level                   20000 non-null  object
#  7   Routine_Task_Percentage     20000 non-null  int64
#  8   Creativity_Requirement      20000 non-null  int64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  object
#  11  Number_of_AI_Tools_Used     20000 non-null  int64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  int64
#  13  Tasks_Automated_Percentage  20000 non-null  int64
#  14  AI_Training_Hours           20000 non-null  int64
#  15  Layoff_Risk                 20000 non-null  object
# dtypes: int64(9), object(7)
# memory usage: 2.4+ MB

# %%
ai.head()
# Out:
#    Age Education_Level  Years_of_Experience       Industry  \
# 0   59        Master's                    6        Finance
# 1   44        Master's                   14  Manufacturing
# 2   36      Bachelor's                    7         Retail
# 3   27      Bachelor's                    6        Finance
# 4   49     High School                   12        Finance
#
#                 Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0             Accountant       Medium     Entry                       84
# 1  Production Supervisor        Small     Entry                       30
# 2          Store Manager       Medium    Senior                       12
# 3                Auditor        Large     Entry                       90
# 4                Auditor        Small     Entry                       49
#
#    Creativity_Requirement  Human_Interaction_Level AI_Adoption_Level  \
# 0                      21                       94            Medium
# 1                      84                       68               Low
# 2                      86                       71               Low
# 3                      18                       21            Medium
# 4                      52                       72            Medium
#
#    Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# 0                        5                        7
# 1                        2                        2
# 2                        0                        1
# 3                        3                       10
# 4                        5                       13
#
#    Tasks_Automated_Percentage  AI_Training_Hours Layoff_Risk
# 0                          40                 26        High
# 1                          14                  9         Low
# 2                           6                  3         Low
# 3                          67                 26        High
# 4                          26                 19      Medium

# %%
ai.isnull().sum()
# Out:
# Age                           0
# Education_Level               0
# Years_of_Experience           0
# Industry                      0
# Job_Role                      0
# Company_Size                  0
# Job_Level                     0
# Routine_Task_Percentage       0
# Creativity_Requirement        0
# Human_Interaction_Level       0
# AI_Adoption_Level             0
# Number_of_AI_Tools_Used       0
# AI_Usage_Hours_Per_Week       0
# Tasks_Automated_Percentage    0
# AI_Training_Hours             0
# Layoff_Risk                   0
# dtype: int64

# %%
ai[["Tasks_Automated_Percentage","Layoff_Risk"]]
# Out:
#        Tasks_Automated_Percentage Layoff_Risk
# 0                              40        High
# 1                              14         Low
# 2                               6         Low
# 3                              67        High
# 4                              26      Medium
# ...                           ...         ...
# 19995                          16      Medium
# 19996                          77        High
# 19997                          55        High
# 19998                          66      Medium
# 19999                          30      Medium
#
# [20000 rows x 2 columns]

# %%
ai.head()
# Out:
#    Age Education_Level  Years_of_Experience       Industry  \
# 0   59        Master's                    6        Finance
# 1   44        Master's                   14  Manufacturing
# 2   36      Bachelor's                    7         Retail
# 3   27      Bachelor's                    6        Finance
# 4   49     High School                   12        Finance
#
#                 Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0             Accountant       Medium     Entry                       84
# 1  Production Supervisor        Small     Entry                       30
# 2          Store Manager       Medium    Senior                       12
# 3                Auditor        Large     Entry                       90
# 4                Auditor        Small     Entry                       49
#
#    Creativity_Requirement  Human_Interaction_Level AI_Adoption_Level  \
# 0                      21                       94            Medium
# 1                      84                       68               Low
# 2                      86                       71               Low
# 3                      18                       21            Medium
# 4                      52                       72            Medium
#
#    Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# 0                        5                        7
# 1                        2                        2
# 2                        0                        1
# 3                        3                       10
# 4                        5                       13
#
#    Tasks_Automated_Percentage  AI_Training_Hours Layoff_Risk
# 0                          40                 26        High
# 1                          14                  9         Low
# 2                           6                  3         Low
# 3                          67                 26        High
# 4                          26                 19      Medium

# %%
ai[["Creativity_Requirement","AI_Adoption_Level",	"Number_of_AI_Tools_Used","Layoff_Risk"]].tail(10)
# Out:
#        Creativity_Requirement AI_Adoption_Level  Number_of_AI_Tools_Used  \
# 19990                      60            Medium                        4
# 19991                     100               Low                        2
# 19992                      73               Low                        0
# 19993                      29            Medium                        2
# 19994                      61               Low                        2
# 19995                      62               Low                        0
# 19996                      20              High                        9
# 19997                       2            Medium                        2
# 19998                      40            Medium                        3
# 19999                      65               Low                        1
#
#       Layoff_Risk
# 19990      Medium
# 19991         Low
# 19992         Low
# 19993        High
# 19994      Medium
# 19995      Medium
# 19996        High
# 19997        High
# 19998      Medium
# 19999      Medium

# %%
import matplotlib.pyplot as plt

ai[["Tasks_Automated_Percentage",
    "Years_of_Experience",
    "Routine_Task_Percentage",
    "Layoff_Risk"]].plot(
        kind="bar",
        figsize=(20, 10)
)

plt.show()

# %%
# Dataset shape
ai.shape
# Out:
# (20000, 16)

# %%
# Data types
ai.dtypes
# Out:
# Age                            int64
# Education_Level               object
# Years_of_Experience            int64
# Industry                      object
# Job_Role                      object
# Company_Size                  object
# Job_Level                     object
# Routine_Task_Percentage        int64
# Creativity_Requirement         int64
# Human_Interaction_Level        int64
# AI_Adoption_Level             object
# Number_of_AI_Tools_Used        int64
# AI_Usage_Hours_Per_Week        int64
# Tasks_Automated_Percentage     int64
# AI_Training_Hours              int64
# Layoff_Risk                   object
# dtype: object

# %%
# Statistical summary
ai.describe()
# Out:
#                 Age  Years_of_Experience  Routine_Task_Percentage  \
# count  20000.000000         20000.000000             20000.000000
# mean      40.361500             7.265500                51.885500
# std       11.526333             4.720606                24.437808
# min       21.000000             0.000000                10.000000
# 25%       30.000000             4.000000                31.000000
# 50%       40.000000             7.000000                52.000000
# 75%       50.000000            11.000000                73.000000
# max       60.000000            32.000000                94.000000
#
#        Creativity_Requirement  Human_Interaction_Level  \
# count            20000.000000             20000.000000
# mean                47.786700                60.055000
# std                 26.100482                22.267801
# min                  0.000000                20.000000
# 25%                 27.000000                41.000000
# 50%                 48.000000                62.000000
# 75%                 69.000000                79.000000
# max                100.000000                99.000000
#
#        Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# count             20000.000000              20000.00000
# mean                  2.460350                  6.77395
# std                   2.097486                  6.08637
# min                   0.000000                  0.00000
# 25%                   1.000000                  2.00000
# 50%                   2.000000                  5.00000
# 75%                   4.000000                 10.00000
# max                  10.000000                 30.00000
#
#        Tasks_Automated_Percentage  AI_Training_Hours
# count                 20000.00000       20000.000000
# mean                     37.22895          12.621400
# std                      19.99512          13.552647
# min                       4.00000           0.000000
# 25%                      21.00000           4.000000
# 50%                      35.00000           8.000000
# 75%                      51.00000          18.000000
# max                      93.00000          79.000000

# %%
# Unique values
ai.nunique()
# Out:
# Age                            40
# Education_Level                 4
# Years_of_Experience            27
# Industry                        8
# Job_Role                       24
# Company_Size                    3
# Job_Level                       3
# Routine_Task_Percentage        85
# Creativity_Requirement        101
# Human_Interaction_Level        80
# AI_Adoption_Level               3
# Number_of_AI_Tools_Used        11
# AI_Usage_Hours_Per_Week        31
# Tasks_Automated_Percentage     90
# AI_Training_Hours              80
# Layoff_Risk                     3
# dtype: int64

# %%
# Distribution
ai.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Years_of_Experience'}>,
#         <Axes: title={'center': 'Routine_Task_Percentage'}>],
#        [<Axes: title={'center': 'Creativity_Requirement'}>,
#         <Axes: title={'center': 'Human_Interaction_Level'}>,
#         <Axes: title={'center': 'Number_of_AI_Tools_Used'}>],
#        [<Axes: title={'center': 'AI_Usage_Hours_Per_Week'}>,
#         <Axes: title={'center': 'Tasks_Automated_Percentage'}>,
#         <Axes: title={'center': 'AI_Training_Hours'}>]], dtype=object)

# %%
ai["Layoff_Risk"].value_counts()
# Out:
# Layoff_Risk
# High      6797
# Low       6602
# Medium    6601
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.boxplot(data=ai, x="Layoff_Risk",
            y="Tasks_Automated_Percentage")
# Out:
# <Axes: xlabel='Layoff_Risk', ylabel='Tasks_Automated_Percentage'>

# %%
sns.boxplot(data=ai, x="Layoff_Risk",
            y="AI_Usage_Hours_Per_Week")
# Out:
# <Axes: xlabel='Layoff_Risk', ylabel='AI_Usage_Hours_Per_Week'>

# %%
sns.scatterplot(
    data=ai,
    x="AI_Adoption_Level",
    y="Tasks_Automated_Percentage",
    hue="Layoff_Risk"
)
# Out:
# <Axes: xlabel='AI_Adoption_Level', ylabel='Tasks_Automated_Percentage'>

# %%
sns.heatmap(
    ai.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)
# Out:
# <Axes: >
