# %%
import pandas as pd
a1=pd.read_csv("/content/wc_2026_fixtures.csv")
a1
# Out:
#     group            stage        team1         team2              venue  \
# 0       A      Group Stage       Mexico  South Africa     Estadio Azteca
# 1       A      Group Stage  South Korea       Czechia      Estadio Akron
# 2       A      Group Stage  South Korea        Mexico      Estadio Akron
# 3       A      Group Stage      Czechia  South Africa      Estadio Akron
# 4       A      Group Stage      Czechia        Mexico     Estadio Azteca
# ..    ...              ...          ...           ...                ...
# 99    NaN    Quarter-final          QF7           QF8        NRG Stadium
# 100   NaN       Semi-final          SF1           SF2       AT&T Stadium
# 101   NaN       Semi-final          SF3           SF4    MetLife Stadium
# 102   NaN  3rd Place Match    3rd Place     3rd Place  Hard Rock Stadium
# 103   NaN            Final   Finalist 1    Finalist 2    MetLife Stadium
#
#                 city country        date kickoff_et team1_confederation  \
# ...

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   group                72 non-null     object
#  1   stage                104 non-null    object
#  2   team1                104 non-null    object
#  3   team2                104 non-null    object
#  4   venue                104 non-null    object
#  5   city                 104 non-null    object
#  6   country              104 non-null    object
#  7   date                 104 non-null    object
#  8   kickoff_et           104 non-null    object
#  9   team1_confederation  72 non-null     object
#  10  team1_fifa_rank      72 non-null     float64
#  11  team1_coach          72 non-null     object
#  12  team2_confederation  72 non-null     object
#  13  team2_fifa_rank      72 non-null     float64
#  14  team2_coach          72 non-null     object
# ...

# %%
a1.isnull().sum()
# Out:
# group                  32
# stage                   0
# team1                   0
# team2                   0
# venue                   0
# city                    0
# country                 0
# date                    0
# kickoff_et              0
# team1_confederation    32
# team1_fifa_rank        32
# team1_coach            32
# team2_confederation    32
# team2_fifa_rank        32
# team2_coach            32
# dtype: int64

# %%
type(a1["team1_fifa_rank"][0])
# Out:
# numpy.float64

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   group                72 non-null     object
#  1   stage                104 non-null    object
#  2   team1                104 non-null    object
#  3   team2                104 non-null    object
#  4   venue                104 non-null    object
#  5   city                 104 non-null    object
#  6   country              104 non-null    object
#  7   date                 104 non-null    object
#  8   kickoff_et           104 non-null    object
#  9   team1_confederation  72 non-null     object
#  10  team1_fifa_rank      72 non-null     float64
#  11  team1_coach          72 non-null     object
#  12  team2_confederation  72 non-null     object
#  13  team2_fifa_rank      72 non-null     float64
#  14  team2_coach          72 non-null     object
# ...

# %%
a1.isnull().sum()
# Out:
# group                  32
# stage                   0
# team1                   0
# team2                   0
# venue                   0
# city                    0
# country                 0
# date                    0
# kickoff_et              0
# team1_confederation    32
# team1_fifa_rank        32
# team1_coach            32
# team2_confederation    32
# team2_fifa_rank        32
# team2_coach            32
# dtype: int64

# %%
a1.head()
# Out:
#   group        stage        team1         team2           venue         city  \
# 0     A  Group Stage       Mexico  South Africa  Estadio Azteca  Mexico City
# 1     A  Group Stage  South Korea       Czechia   Estadio Akron  Guadalajara
# 2     A  Group Stage  South Korea        Mexico   Estadio Akron  Guadalajara
# 3     A  Group Stage      Czechia  South Africa   Estadio Akron  Guadalajara
# 4     A  Group Stage      Czechia        Mexico  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF             15.0
# 1  Mexico  2026-06-11   22:00 ET                 AFC             25.0
# 2  Mexico  2026-06-18   21:00 ET                 AFC             25.0
# 3  Mexico  2026-06-18   18:00 ET                UEFA             41.0
# 4  Mexico  2026-06-24   21:00 ET                UEFA             41.0
#
#       team1_coach team2_confederation  team2_fifa_rank     team2_coach
# ...

# %%
a1.tail()
# Out:
#     group            stage       team1       team2              venue  \
# 99    NaN    Quarter-final         QF7         QF8        NRG Stadium
# 100   NaN       Semi-final         SF1         SF2       AT&T Stadium
# 101   NaN       Semi-final         SF3         SF4    MetLife Stadium
# 102   NaN  3rd Place Match   3rd Place   3rd Place  Hard Rock Stadium
# 103   NaN            Final  Finalist 1  Finalist 2    MetLife Stadium
#
#                 city country        date kickoff_et team1_confederation  \
# 99           Houston     USA  2026-07-11        TBD                 NaN
# 100        Arlington     USA  2026-07-14        TBD                 NaN
# 101  East Rutherford     USA  2026-07-15        TBD                 NaN
# 102            Miami     USA  2026-07-18        TBD                 NaN
# 103  East Rutherford     USA  2026-07-19        TBD                 NaN
#
#      team1_fifa_rank team1_coach team2_confederation  team2_fifa_rank  \
# ...

# %%
a1.describe()
# Out:
#        team1_fifa_rank  team2_fifa_rank
# count        72.000000        72.000000
# mean         30.208333        37.916667
# std          24.521297        23.836739
# min           1.000000         1.000000
# 25%           9.750000        17.750000
# 50%          24.000000        35.500000
# 75%          44.000000        57.750000
# max          95.000000        95.000000

# %%
a1.shape
# Out:
# (104, 15)

# %%
a1.columns
# Out:
# Index(['group', 'stage', 'team1', 'team2', 'venue', 'city', 'country', 'date',
#        'kickoff_et', 'team1_confederation', 'team1_fifa_rank', 'team1_coach',
#        'team2_confederation', 'team2_fifa_rank', 'team2_coach'],
#       dtype='object')

# %%
a1.isnull().sum()
# Out:
# group                  32
# stage                   0
# team1                   0
# team2                   0
# venue                   0
# city                    0
# country                 0
# date                    0
# kickoff_et              0
# team1_confederation    32
# team1_fifa_rank        32
# team1_coach            32
# team2_confederation    32
# team2_fifa_rank        32
# team2_coach            32
# dtype: int64

# %%
type(a1["team1_fifa_rank"][10])
# Out:
# numpy.float64

# %%
print(a1["team1_fifa_rank"].dtype)
# Out:
# float64

# %%
a1["simulated_object_rank"]=(a1["team1_fifa_rank"]).astype(str)

# %%
print(a1["simulated_object_rank"].dtype)
# Out:
# object

# %%
# Convert 'team1_fifa_rank' and 'team2_fifa_rank' to nullable integer type
# 'Int64' allows integer columns to have NaN values
a1["team1_fifa_rank"]=a1["team1_fifa_rank"].astype("Int64")
a1["team2_fifa_rank"]=a1["team2_fifa_rank"].astype("Int64")

# %%
print("Data types after converting FIFA rank columns:")
a1.info()
# Out:
# Data types after converting FIFA rank columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   group                  72 non-null     object
#  1   stage                  104 non-null    object
#  2   team1                  104 non-null    object
#  3   team2                  104 non-null    object
#  4   venue                  104 non-null    object
#  5   city                   104 non-null    object
#  6   country                104 non-null    object
#  7   date                   104 non-null    object
#  8   kickoff_et             104 non-null    object
#  9   team1_confederation    72 non-null     object
#  10  team1_fifa_rank        72 non-null     Int64
#  11  team1_coach            72 non-null     object
#  12  team2_confederation    72 non-null     object
# ...

# %%
obj=["group","team1_confederation","team1_coach","team2_confederation","team2_coach"]
for col in obj:
  a1[col]=a1[col].fillna("Unknown")

# %%
print(a1.isnull().sum())
# Out:
# group                     0
# stage                     0
# team1                     0
# team2                     0
# venue                     0
# city                      0
# country                   0
# date                      0
# kickoff_et                0
# team1_confederation       0
# team1_fifa_rank          32
# team1_coach               0
# team2_confederation       0
# team2_fifa_rank          32
# team2_coach               0
# simulated_object_rank     0
# dtype: int64

# %%
a1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   group                  104 non-null    object
#  1   stage                  104 non-null    object
#  2   team1                  104 non-null    object
#  3   team2                  104 non-null    object
#  4   venue                  104 non-null    object
#  5   city                   104 non-null    object
#  6   country                104 non-null    object
#  7   date                   104 non-null    object
#  8   kickoff_et             104 non-null    object
#  9   team1_confederation    104 non-null    object
#  10  team1_fifa_rank        72 non-null     Int64
#  11  team1_coach            104 non-null    object
#  12  team2_confederation    104 non-null    object
#  13  team2_fifa_rank        72 non-null     Int64
# ...

# %%
display(a1.head())
# Out:
#   group        stage        team1         team2           venue         city  \
# 0     A  Group Stage       Mexico  South Africa  Estadio Azteca  Mexico City
# 1     A  Group Stage  South Korea       Czechia   Estadio Akron  Guadalajara
# 2     A  Group Stage  South Korea        Mexico   Estadio Akron  Guadalajara
# 3     A  Group Stage      Czechia  South Africa   Estadio Akron  Guadalajara
# 4     A  Group Stage      Czechia        Mexico  Estadio Azteca  Mexico City
#
#   country        date kickoff_et team1_confederation  team1_fifa_rank  \
# 0  Mexico  2026-06-11   20:00 ET            CONCACAF               15
# 1  Mexico  2026-06-11   22:00 ET                 AFC               25
# 2  Mexico  2026-06-18   21:00 ET                 AFC               25
# 3  Mexico  2026-06-18   18:00 ET                UEFA               41
# 4  Mexico  2026-06-24   21:00 ET                UEFA               41
#
#       team1_coach team2_confederation  team2_fifa_rank     team2_coach  \
# ...

# %%
a1['team1_fifa_rank'] = a1['team1_fifa_rank'].fillna(-1)
a1['team2_fifa_rank'] = a1['team2_fifa_rank'].fillna(-1)

# %%
a1
# Out:
#        group            stage        team1         team2              venue  \
# 0          A      Group Stage       Mexico  South Africa     Estadio Azteca
# 1          A      Group Stage  South Korea       Czechia      Estadio Akron
# 2          A      Group Stage  South Korea        Mexico      Estadio Akron
# 3          A      Group Stage      Czechia  South Africa      Estadio Akron
# 4          A      Group Stage      Czechia        Mexico     Estadio Azteca
# ..       ...              ...          ...           ...                ...
# 99   Unknown    Quarter-final          QF7           QF8        NRG Stadium
# 100  Unknown       Semi-final          SF1           SF2       AT&T Stadium
# 101  Unknown       Semi-final          SF3           SF4    MetLife Stadium
# 102  Unknown  3rd Place Match    3rd Place     3rd Place  Hard Rock Stadium
# 103  Unknown            Final   Finalist 1    Finalist 2    MetLife Stadium
#
# ...

# %%
a1.head(10)
# Out:
#   group        stage         team1                   team2           venue  \
# 0     A  Group Stage        Mexico            South Africa  Estadio Azteca
# 1     A  Group Stage   South Korea                 Czechia   Estadio Akron
# 2     A  Group Stage   South Korea                  Mexico   Estadio Akron
# 3     A  Group Stage       Czechia            South Africa   Estadio Akron
# 4     A  Group Stage       Czechia                  Mexico  Estadio Azteca
# 5     A  Group Stage  South Africa             South Korea  Estadio Azteca
# 6     B  Group Stage        Canada  Bosnia and Herzegovina       BMO Field
# 7     B  Group Stage         Qatar             Switzerland     Lumen Field
# 8     B  Group Stage   Switzerland  Bosnia and Herzegovina        BC Place
# 9     B  Group Stage        Canada                   Qatar        BC Place
#
#           city country        date kickoff_et team1_confederation  \
# 0  Mexico City  Mexico  2026-06-11   20:00 ET            CONCACAF
# ...

# %%
a1.tail(10)
# Out:
#        group            stage       team1       team2                  venue  \
# 94   Unknown      Round of 16     R32 W13     R32 W14      Hard Rock Stadium
# 95   Unknown      Round of 16     R32 W15     R32 W16  Mercedes-Benz Stadium
# 96   Unknown    Quarter-final         QF1         QF2           AT&T Stadium
# 97   Unknown    Quarter-final         QF3         QF4        MetLife Stadium
# 98   Unknown    Quarter-final         QF5         QF6              Rose Bowl
# 99   Unknown    Quarter-final         QF7         QF8            NRG Stadium
# 100  Unknown       Semi-final         SF1         SF2           AT&T Stadium
# 101  Unknown       Semi-final         SF3         SF4        MetLife Stadium
# 102  Unknown  3rd Place Match   3rd Place   3rd Place      Hard Rock Stadium
# 103  Unknown            Final  Finalist 1  Finalist 2        MetLife Stadium
#
#                 city country        date kickoff_et team1_confederation  \
# ...

# %%
a1.team1_fifa_rank.value_counts()
# Out:
# team1_fifa_rank
# -1    32
# 42     2
# 41     2
# 30     2
# 19     2
# 6      2
# 10     2
# 16     2
# 8      2
# 40     2
# 2      2
# 1      2
# 17     2
# 7      2
# 9      2
# 24     2
# 25     2
# 68     2
# 13     2
# 11     2
# 4      2
# 3      2
# 5      2
# 44     2
# 95     2
# 64     1
# 26     1
# 83     1
# 47     1
# 35     1
# 60     1
# 52     1
# 15     1
# 70     1
# 57     1
# 21     1
# 29     1
# 81     1
# 33     1
# 39     1
# 18     1
# 36     1
# 23     1
# 61     1
# 14     1
# 51     1
# 62     1
# 65     1
# 53     1
# Name: count, dtype: Int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
a1.team1_fifa_rank.value_counts().plot(kind="pie")
plt.title("Team 1 FIFA Rank")

plt.subplot(1,2,2)
a1.team2_fifa_rank.value_counts().plot(kind="pie")
plt.title("Team 2 FIFA Rank")

plt.show()

# %%
a1["date"] = pd.to_datetime(a1["date"])

# %%
a1["team1_fifa_rank"] = (
    a1["team1_fifa_rank"]
    .astype("Int64")
)

a1["team2_fifa_rank"] = (
    a1["team2_fifa_rank"]
    .astype("Int64")
)

# %%
a1["team1_confederation"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='team1_confederation'>

# %%
a1["team2_confederation"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='team2_confederation'>

# %%
a1["country"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='country'>
