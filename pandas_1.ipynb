# %%
import pandas as pd

# %%
import numpy as np

# %%
a=pd.read_csv("/content/early_wakeup_health_dataset.csv")

# %%
a.describe(include="all").T
# Out:
#                        count unique     top  freq       mean        std  \
# Person_ID              10000  10000  P09984     1        NaN        NaN
# Age                  10000.0    NaN     NaN   NaN    44.6667    17.5172
# Gender                 10000      3    Male  4851        NaN        NaN
# Height_cm            10000.0    NaN     NaN   NaN  168.64916   9.876706
# Weight_kg            10000.0    NaN     NaN   NaN   73.10734   16.29195
# ...                      ...    ...     ...   ...        ...        ...
# Health_Score         10000.0    NaN     NaN   NaN   74.20136  12.266227
# Fitness_Level          10000      4    Good  4429        NaN        NaN
# Healthy_Aging_Score  10000.0    NaN     NaN   NaN   74.81232  14.627688
# Wellness_Category      10000      4    Good  4429        NaN        NaN
# Early_Waker            10000      2      No  5842        NaN        NaN
#
#                        min    25%    50%    75%    max
# ...

# %%
df=pd.DataFrame(a)

# %%
df.head(10)
# Out:
#   Person_ID  Age  Gender  Height_cm  Weight_kg    BMI    Country  \
# 0    P00001   76  Female      158.8       62.1  24.63      Italy
# 1    P00002   49  Female      160.9       68.5  26.45        USA
# 2    P00003   51  Female      151.9       54.8  23.77     Mexico
# 3    P00004   48    Male      167.6       81.3  28.93  Australia
# 4    P00005   68  Female      171.9       75.4  25.51        USA
# 5    P00006   79    Male      166.2       60.5  21.90      India
# 6    P00007   74    Male      169.9       55.0  19.06     Canada
# 7    P00008   67  Female      160.8       82.5  31.91     Brazil
# 8    P00009   22    Male      190.8       65.1  17.88         UK
# 9    P00010   22    Male      177.9       90.7  28.67      Italy
#
#           Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 0       Entrepreneur        Widowed        08:59  ...          Low
# 1         Freelancer         Single        06:35  ...       Medium
# ...

# %%
df.tail(10)
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI   Country  \
# 9990    P09991   56  Female      159.6       48.5  19.03       USA
# 9991    P09992   55  Female      145.4       44.3  20.96     Spain
# 9992    P09993   41  Female      156.8       69.6  28.31   Nigeria
# 9993    P09994   72    Male      167.8       81.4  28.92     India
# 9994    P09995   66    Male      184.1       92.4  27.26  Pakistan
# 9995    P09996   66    Male      170.2       86.4  29.84   Nigeria
# 9996    P09997   70    Male      182.3       86.9  26.14    Canada
# 9997    P09998   29    Male      170.4       81.2  27.96     Italy
# 9998    P09999   22    Male      186.5       78.3  22.52     India
# 9999    P10000   58    Male      177.8       63.9  20.22    Brazil
#
#         Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 9990         Nurse       Divorced        08:25  ...          Low
# 9991  Entrepreneur         Single        09:33  ...          Low
# ...

# %%
df.shape
# Out:
# (10000, 64)

# %%
df.columns
# Out:
# Index(['Person_ID', 'Age', 'Gender', 'Height_cm', 'Weight_kg', 'BMI',
#        'Country', 'Occupation', 'Marital_Status', 'Wake_Up_Time', 'Sleep_Time',
#        'Sleep_Duration_Hours', 'Sleep_Quality_Score',
#        'Number_of_Night_Awakenings', 'Weekend_Sleep_Difference_Hours',
#        'Nap_Frequency_Per_Week', 'Screen_Time_Before_Bed_Hours',
#        'Exercise_Frequency_Per_Week', 'Exercise_Duration_Minutes',
#        'Exercise_Type', 'Daily_Steps', 'Morning_Workout', 'Workout_Intensity',
#        'Gym_Member', 'Daily_Calorie_Intake', 'Water_Intake_Liters',
#        'Fruit_Intake_Per_Day', 'Vegetable_Intake_Per_Day',
#        'Protein_Intake_Grams', 'Sugary_Drinks_Per_Week',
#        'Fast_Food_Meals_Per_Week', 'Breakfast_Regularity_Score',
#        'Smoking_Status', 'Alcohol_Consumption', 'Stress_Level',
#        'Working_Hours_Per_Day', 'Sitting_Hours_Per_Day', 'Outdoor_Time_Hours',
#        'Social_Interaction_Score', 'Meditation_Practice', 'Resting_Heart_Rate',
# ...

# %%
df.dtypes
# Out:
# Person_ID               object
# Age                      int64
# Gender                  object
# Height_cm              float64
# Weight_kg              float64
#                         ...
# Health_Score           float64
# Fitness_Level           object
# Healthy_Aging_Score    float64
# Wellness_Category       object
# Early_Waker             object
# Length: 64, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Person_ID                       10000 non-null  object
#  1   Age                             10000 non-null  int64
#  2   Gender                          10000 non-null  object
#  3   Height_cm                       10000 non-null  float64
#  4   Weight_kg                       10000 non-null  float64
#  5   BMI                             10000 non-null  float64
#  6   Country                         10000 non-null  object
#  7   Occupation                      10000 non-null  object
#  8   Marital_Status                  10000 non-null  object
#  9   Wake_Up_Time                    10000 non-null  object
#  10  Sleep_Time                      10000 non-null  object
#  11  Sleep_Duration_Hours            10000 non-null  float64
# ...

# %%
df[["Age","Early_Waker","Diabetes_Risk"]]
# Out:
#       Age Early_Waker Diabetes_Risk
# 0      76          No        Medium
# 1      49          No        Medium
# 2      51          No        Medium
# 3      48          No           Low
# 4      68          No        Medium
# ...   ...         ...           ...
# 9995   66          No          High
# 9996   70          No        Medium
# 9997   29          No        Medium
# 9998   22          No        Medium
# 9999   58         Yes           Low
#
# [10000 rows x 3 columns]

# %%
df.iloc[1000]
# Out:
# Person_ID                 P01001
# Age                           41
# Gender                      Male
# Height_cm                  162.9
# Weight_kg                   65.8
#                          ...
# Health_Score                82.9
# Fitness_Level          Excellent
# Healthy_Aging_Score         78.5
# Wellness_Category      Excellent
# Early_Waker                  Yes
# Name: 1000, Length: 64, dtype: object

# %%
df[a["Age"]>60]
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI   Country  \
# 0       P00001   76  Female      158.8       62.1  24.63     Italy
# 4       P00005   68  Female      171.9       75.4  25.51       USA
# 5       P00006   79    Male      166.2       60.5  21.90     India
# 6       P00007   74    Male      169.9       55.0  19.06    Canada
# 7       P00008   67  Female      160.8       82.5  31.91    Brazil
# ...        ...  ...     ...        ...        ...    ...       ...
# 9989    P09990   80    Male      180.2       88.2  27.18    Canada
# 9993    P09994   72    Male      167.8       81.4  28.92     India
# 9994    P09995   66    Male      184.1       92.4  27.26  Pakistan
# 9995    P09996   66    Male      170.2       86.4  29.84   Nigeria
# 9996    P09997   70    Male      182.3       86.9  26.14    Canada
#
#              Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 0          Entrepreneur        Widowed        08:59  ...          Low
# ...

# %%
df[(df["Age"]>40)&(df["Gender"]=="Male")]
# Out:
#      Person_ID  Age Gender  Height_cm  Weight_kg    BMI    Country  \
# 3       P00004   48   Male      167.6       81.3  28.93  Australia
# 5       P00006   79   Male      166.2       60.5  21.90      India
# 6       P00007   74   Male      169.9       55.0  19.06     Canada
# 10      P00011   54   Male      174.0       65.2  21.54         UK
# 11      P00012   44   Male      183.6       75.2  22.30     France
# ...        ...  ...    ...        ...        ...    ...        ...
# 9993    P09994   72   Male      167.8       81.4  28.92      India
# 9994    P09995   66   Male      184.1       92.4  27.26   Pakistan
# 9995    P09996   66   Male      170.2       86.4  29.84    Nigeria
# 9996    P09997   70   Male      182.3       86.9  26.14     Canada
# 9999    P10000   58   Male      177.8       63.9  20.22     Brazil
#
#              Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 3               Laborer         Single        08:36  ...       Medium
# ...

# %%
df.sort_values("Height_cm",ascending=False)
# Out:
#      Person_ID  Age      Gender  Height_cm  Weight_kg    BMI   Country  \
# 7638    P07639   35        Male      205.5      123.8  29.33     India
# 3408    P03409   72        Male      203.7      127.9  30.82        UK
# 9695    P09696   57        Male      202.8      103.4  25.14    Brazil
# 5956    P05957   58        Male      202.3       67.7  16.54     Italy
# 6080    P06081   42        Male      200.6       76.6  19.03     India
# ...        ...  ...         ...        ...        ...    ...       ...
# 642     P00643   64  Non-binary      145.0       60.4  28.71     Spain
# 5102    P05103   49      Female      145.0       65.0  30.91   Nigeria
# 5142    P05143   44      Female      145.0       50.2  23.86  Pakistan
# 5337    P05338   25      Female      145.0       39.9  19.00    France
# 9909    P09910   56      Female      145.0       42.4  20.15    Brazil
#
#              Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# ...

# %%
df.sort_values(["Age","Weight_kg"],ascending=False)
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI   Country  \
# 3821    P03822   80    Male      187.5      124.9  35.53    Mexico
# 3261    P03262   80    Male      193.2      124.7  33.41     Italy
# 1405    P01406   80    Male      181.4      119.9  36.43    Canada
# 1436    P01437   80    Male      179.2      111.6  34.76  Pakistan
# 7398    P07399   80    Male      180.6      110.0  33.73     India
# ...        ...  ...     ...        ...        ...    ...       ...
# 5868    P05869   18    Male      156.6       45.8  18.69  Pakistan
# 7876    P07877   18    Male      166.7       44.5  16.00     India
# 5088    P05089   18  Female      165.7       43.9  16.00       USA
# 3694    P03695   18  Female      152.3       41.7  17.99  Pakistan
# 4277    P04278   18  Female      155.3       38.6  16.00     Italy
#
#              Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 3821            Retired        Married        09:27  ...         High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Person_ID                       10000 non-null  object
#  1   Age                             10000 non-null  int64
#  2   Gender                          10000 non-null  object
#  3   Height_cm                       10000 non-null  float64
#  4   Weight_kg                       10000 non-null  float64
#  5   BMI                             10000 non-null  float64
#  6   Country                         10000 non-null  object
#  7   Occupation                      10000 non-null  object
#  8   Marital_Status                  10000 non-null  object
#  9   Wake_Up_Time                    10000 non-null  object
#  10  Sleep_Time                      10000 non-null  object
#  11  Sleep_Duration_Hours            10000 non-null  float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Alcohol_Consumption    3014
# Workout_Intensity       824
# Exercise_Type           824
# Person_ID                 0
# Weight_kg                 0
#                        ...
# Health_Score              0
# Fitness_Level             0
# Healthy_Aging_Score       0
# Wellness_Category         0
# Early_Waker               0
# Length: 64, dtype: int64

# %%
df.columns
# Out:
# Index(['Person_ID', 'Age', 'Gender', 'Height_cm', 'Weight_kg', 'BMI',
#        'Country', 'Occupation', 'Marital_Status', 'Wake_Up_Time', 'Sleep_Time',
#        'Sleep_Duration_Hours', 'Sleep_Quality_Score',
#        'Number_of_Night_Awakenings', 'Weekend_Sleep_Difference_Hours',
#        'Nap_Frequency_Per_Week', 'Screen_Time_Before_Bed_Hours',
#        'Exercise_Frequency_Per_Week', 'Exercise_Duration_Minutes',
#        'Exercise_Type', 'Daily_Steps', 'Morning_Workout', 'Workout_Intensity',
#        'Gym_Member', 'Daily_Calorie_Intake', 'Water_Intake_Liters',
#        'Fruit_Intake_Per_Day', 'Vegetable_Intake_Per_Day',
#        'Protein_Intake_Grams', 'Sugary_Drinks_Per_Week',
#        'Fast_Food_Meals_Per_Week', 'Breakfast_Regularity_Score',
#        'Smoking_Status', 'Alcohol_Consumption', 'Stress_Level',
#        'Working_Hours_Per_Day', 'Sitting_Hours_Per_Day', 'Outdoor_Time_Hours',
#        'Social_Interaction_Score', 'Meditation_Practice', 'Resting_Heart_Rate',
# ...

# %%
f=df["Alcohol_Consumption"].dropna(inplace=True)
f

# %%
df.columns
# Out:
# Index(['Person_ID', 'Age', 'Gender', 'Height_cm', 'Weight_kg', 'BMI',
#        'Country', 'Occupation', 'Marital_Status', 'Wake_Up_Time', 'Sleep_Time',
#        'Sleep_Duration_Hours', 'Sleep_Quality_Score',
#        'Number_of_Night_Awakenings', 'Weekend_Sleep_Difference_Hours',
#        'Nap_Frequency_Per_Week', 'Screen_Time_Before_Bed_Hours',
#        'Exercise_Frequency_Per_Week', 'Exercise_Duration_Minutes',
#        'Exercise_Type', 'Daily_Steps', 'Morning_Workout', 'Workout_Intensity',
#        'Gym_Member', 'Daily_Calorie_Intake', 'Water_Intake_Liters',
#        'Fruit_Intake_Per_Day', 'Vegetable_Intake_Per_Day',
#        'Protein_Intake_Grams', 'Sugary_Drinks_Per_Week',
#        'Fast_Food_Meals_Per_Week', 'Breakfast_Regularity_Score',
#        'Smoking_Status', 'Alcohol_Consumption', 'Stress_Level',
#        'Working_Hours_Per_Day', 'Sitting_Hours_Per_Day', 'Outdoor_Time_Hours',
#        'Social_Interaction_Score', 'Meditation_Practice', 'Resting_Heart_Rate',
# ...

# %%
df.rename(columns={"Early_Waker":"Early"},inplace=True)

# %%
df.columns
# Out:
# Index(['Person_ID', 'Age', 'Gender', 'Height_cm', 'Weight_kg', 'BMI',
#        'Country', 'Occupation', 'Marital_Status', 'Wake_Up_Time', 'Sleep_Time',
#        'Sleep_Duration_Hours', 'Sleep_Quality_Score',
#        'Number_of_Night_Awakenings', 'Weekend_Sleep_Difference_Hours',
#        'Nap_Frequency_Per_Week', 'Screen_Time_Before_Bed_Hours',
#        'Exercise_Frequency_Per_Week', 'Exercise_Duration_Minutes',
#        'Exercise_Type', 'Daily_Steps', 'Morning_Workout', 'Workout_Intensity',
#        'Gym_Member', 'Daily_Calorie_Intake', 'Water_Intake_Liters',
#        'Fruit_Intake_Per_Day', 'Vegetable_Intake_Per_Day',
#        'Protein_Intake_Grams', 'Sugary_Drinks_Per_Week',
#        'Fast_Food_Meals_Per_Week', 'Breakfast_Regularity_Score',
#        'Smoking_Status', 'Alcohol_Consumption', 'Stress_Level',
#        'Working_Hours_Per_Day', 'Sitting_Hours_Per_Day', 'Outdoor_Time_Hours',
#        'Social_Interaction_Score', 'Meditation_Practice', 'Resting_Heart_Rate',
# ...

# %%
df.drop("arly_Waker",axis=1)
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI    Country  \
# 0       P00001   76  Female      158.8       62.1  24.63      Italy
# 1       P00002   49  Female      160.9       68.5  26.45        USA
# 2       P00003   51  Female      151.9       54.8  23.77     Mexico
# 3       P00004   48    Male      167.6       81.3  28.93  Australia
# 4       P00005   68  Female      171.9       75.4  25.51        USA
# ...        ...  ...     ...        ...        ...    ...        ...
# 9995    P09996   66    Male      170.2       86.4  29.84    Nigeria
# 9996    P09997   70    Male      182.3       86.9  26.14     Canada
# 9997    P09998   29    Male      170.4       81.2  27.96      Italy
# 9998    P09999   22    Male      186.5       78.3  22.52      India
# 9999    P10000   58    Male      177.8       63.9  20.22     Brazil
#
#              Occupation Marital_Status Wake_Up_Time  ... Obesity_Risk  \
# 0          Entrepreneur        Widowed        08:59  ...          Low
# ...

# %%
df["Sitting_Hours_Per_Day"].unique()
# Out:
# array([ 7.9,  4.8,  7.4,  7.1,  4. ,  4.6,  7.3,  6.9,  5.5,  5.7,  7. ,
#         8.1,  5.2,  4.5,  6.4,  4.2,  6.3,  5.6,  5.1,  9.6,  2.6,  8.3,
#         6.2,  6.5, 10.2,  9. ,  8.9,  6. ,  7.5,  8.5,  3.8,  9.3, 10.4,
#         9.9, 10.1,  6.8,  8.2, 10.9,  9.7,  6.1, 10.6, 10.5,  7.7,  5.9,
#         8.4,  5.4,  6.7,  8. ,  7.6,  7.2,  9.5,  7.8,  9.1, 10.7,  9.4,
#         4.9,  9.2, 11.4, 12.8,  8.7,  6.6,  3.4,  9.8,  3.9,  4.3,  3.6,
#         8.6, 10.3,  3.5, 11.1,  3.7, 11.2,  2. ,  4.4,  2.3,  5.3, 11.5,
#         5. , 11. ,  8.8, 10.8,  5.8,  1.7, 11.8, 12. ,  3.1, 10. ,  3.2,
#         4.7, 11.9, 12.2, 12.5, 11.7,  2.2, 12.6, 11.6, 12.4, 11.3,  3. ,
#         2.7, 13. ,  4.1,  1.8,  1.6, 13.7,  2.9, 12.1,  2.1, 12.3,  3.3,
#        13.4, 12.9, 13.5,  2.8,  1. , 14. ,  1.1, 13.1,  1.3,  1.9,  2.5,
#        12.7, 13.3,  2.4, 13.2, 13.9,  1.5,  1.4, 13.6])

# %%
df["Sitting_Hours_Per_Day"].nunique()
# Out:
# 129

# %%
df["Sitting_Hours_Per_Day"].value_counts()
# Out:
# Sitting_Hours_Per_Day
# 8.0     230
# 7.9     220
# 7.1     210
# 7.5     204
# 7.3     196
#        ...
# 1.9       3
# 13.6      3
# 13.9      3
# 1.6       2
# 1.3       2
# Name: count, Length: 129, dtype: int64

# %%
df["Sitting_Hours_Per_Day"].mean()
# Out:
# np.float64(7.59335)

# %%
df["Sitting_Hours_Per_Day"].median()
# Out:
# 7.6

# %%
df["Sitting_Hours_Per_Day"].mode()
# Out:
# 0    8.0
# Name: Sitting_Hours_Per_Day, dtype: float64

# %%
df["Sitting_Hours_Per_Day"].max()
# Out:
# 14.0

# %%
df["Sitting_Hours_Per_Day"].min()
# Out:
# 1.0

# %%
df.groupby("Weight_kg")["Outdoor_Time_Hours"].agg(["mean","max","median"])
# Out:
#            mean   max  median
# Weight_kg
# 33.6       2.48  2.48    2.48
# 35.0       5.46  5.46    5.46
# 35.1       1.73  1.73    1.73
# 35.7       1.19  1.19    1.19
# 36.0       7.94  7.94    7.94
# ...         ...   ...     ...
# 136.8      1.41  1.41    1.41
# 139.0      3.65  3.65    3.65
# 143.9      6.03  6.03    6.03
# 152.0      1.00  1.00    1.00
# 166.6      3.01  3.01    3.01
#
# [847 rows x 3 columns]

# %%
df.duplicated().unique()
# Out:
# array([False])

# %%
df.drop_duplicates()
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI    Country  \
# 0       P00001   76  Female      158.8       62.1  24.63      Italy
# 1       P00002   49  Female      160.9       68.5  26.45        USA
# 2       P00003   51  Female      151.9       54.8  23.77     Mexico
# 3       P00004   48    Male      167.6       81.3  28.93  Australia
# 4       P00005   68  Female      171.9       75.4  25.51        USA
# ...        ...  ...     ...        ...        ...    ...        ...
# 9995    P09996   66    Male      170.2       86.4  29.84    Nigeria
# 9996    P09997   70    Male      182.3       86.9  26.14     Canada
# 9997    P09998   29    Male      170.4       81.2  27.96      Italy
# 9998    P09999   22    Male      186.5       78.3  22.52      India
# 9999    P10000   58    Male      177.8       63.9  20.22     Brazil
#
#              Occupation Marital_Status Wake_Up_Time  ... Hypertension_Risk  \
# ...

# %%
df["Height_cm"]=df["Height_cm"].astype(int)
df
# Out:
#      Person_ID  Age  Gender  Height_cm  Weight_kg    BMI    Country  \
# 0       P00001   76  Female        158       62.1  24.63      Italy
# 1       P00002   49  Female        160       68.5  26.45        USA
# 2       P00003   51  Female        151       54.8  23.77     Mexico
# 3       P00004   48    Male        167       81.3  28.93  Australia
# 4       P00005   68  Female        171       75.4  25.51        USA
# ...        ...  ...     ...        ...        ...    ...        ...
# 9995    P09996   66    Male        170       86.4  29.84    Nigeria
# 9996    P09997   70    Male        182       86.9  26.14     Canada
# 9997    P09998   29    Male        170       81.2  27.96      Italy
# 9998    P09999   22    Male        186       78.3  22.52      India
# 9999    P10000   58    Male        177       63.9  20.22     Brazil
#
#              Occupation Marital_Status Wake_Up_Time  ... Hypertension_Risk  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 65 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Person_ID                       10000 non-null  object
#  1   Age                             10000 non-null  int64
#  2   Gender                          10000 non-null  object
#  3   Height_cm                       10000 non-null  int64
#  4   Weight_kg                       10000 non-null  float64
#  5   BMI                             10000 non-null  float64
#  6   Country                         10000 non-null  object
#  7   Occupation                      10000 non-null  object
#  8   Marital_Status                  10000 non-null  object
#  9   Wake_Up_Time                    10000 non-null  object
#  10  Sleep_Time                      10000 non-null  object
#  11  Sleep_Duration_Hours            10000 non-null  float64
# ...

# %%
df.sample(10)
# Out:
#      Person_ID  Age      Gender  Height_cm  Weight_kg    BMI   Country  \
# 4343    P04344   75        Male        166       69.4  25.16     Japan
# 777     P00778   28        Male        188       81.1  22.84     India
# 6142    P06143   21        Male        180       94.9  29.10    Canada
# 5439    P05440   23        Male        167       65.5  23.49       USA
# 4392    P04393   63      Female        169       72.9  25.36   Nigeria
# 4533    P04534   23        Male        156       60.8  24.68    France
# 2083    P02084   62  Non-binary        164       80.0  29.45  Pakistan
# 6954    P06955   50        Male        160       68.3  26.54       USA
# 2349    P02350   71        Male        171       68.4  23.16    France
# 5221    P05222   50      Female        158       71.0  28.20    Mexico
#
#              Occupation Marital_Status Wake_Up_Time  ... Hypertension_Risk  \
# 4343  Software Engineer        Married        06:54  ...              High
# ...

# %%
df.select_dtypes(include="object")
# Out:
#      Person_ID  Gender    Country         Occupation Marital_Status  \
# 0       P00001  Female      Italy       Entrepreneur        Widowed
# 1       P00002  Female        USA         Freelancer         Single
# 2       P00003  Female     Mexico              Nurse         Single
# 3       P00004    Male  Australia            Laborer         Single
# 4       P00005  Female        USA  Software Engineer        Married
# ...        ...     ...        ...                ...            ...
# 9995    P09996    Male    Nigeria            Teacher         Single
# 9996    P09997    Male     Canada            Athlete         Single
# 9997    P09998    Male      Italy             Lawyer        Married
# 9998    P09999    Male      India               Chef         Single
# 9999    P10000    Male     Brazil         Freelancer         Single
#
#      Wake_Up_Time Sleep_Time    Exercise_Type Morning_Workout  \
# 0           08:59      01:29  Weight Training              No
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)
